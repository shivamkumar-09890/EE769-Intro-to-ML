# %%
import pandas as pd # for reading the csv file
import numpy as np #
import matplotlib as plt # for ploting the grap
import seaborn as sns # for using better visualization technique
# Out:
# C:\Users\Shivam\anaconda3\lib\site-packages\scipy\__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.25.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
df_aff_hou_pro = pd.read_csv("LAHD_Affordable_Housing_Projects_List__2003_to_Present_.csv") # used pandas to read the csv file and then stored it under dataset1

# %%
df_res_mkt_hel = pd.read_csv("Restaurant_and_Market_Health_Inspections.csv")

# %% [markdown]
# ### (b) Performing EDA on df_aff_hou_pro and df_res_mkt_hel

# %% [markdown]
# #### (b-1)  Check for the data types and analyses of df_aff_hou_pro

# %% [markdown]
# ##### Head

# %%
df_aff_hou_pro.head(10) #this is to look at the first few columns of data. we canhl also write head(n) where n is no. of rows to be veiwed. the default value of n is 5.
# Out:
#           APN PROJECT NUMBER                                             NAME  \
# 0  5143020023      02-118256                             SAN LUCAS APARTMENTS
# 1  5050011005      05-117193                           LEEWARD APTS. (SITE 7)
# 2  5114014020      14-121652                          FLORENCE MILLS (SITE 5)
# 3  4012018025          60013                        MORGAN PLACE SENIOR APTS.
# 4  5153030026          50036                                   WITMER HEIGHTS
# 5  5127029049      18-125459         LA PRENSA LIBRE- 9% (FKA WASHINGTON/ LA)
# 6  5037025018      14-121612                                        KING 1101
# 7  5119011019      13-120909  ROBERTA STEPHENS VILLAS I & II (RECAP) (SITE 2)
# 8  4286030020      24-131812         ADDA & PAUL SAFRAN SENIOR HOUSING(RECAP)
# 9  5110025032      10-117556                               SUNRISE APARTMENTS
#
#   DEVELOPMENT STAGE    CONSTRUCTION TYPE  \
# 0        In-Service     NEW CONSTRUCTION
# ...

# %% [markdown]
# ###### Info

# %%
df_aff_hou_pro.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 595 entries, 0 to 594
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   APN                      595 non-null    int64
#  1   PROJECT NUMBER           595 non-null    object
#  2   NAME                     595 non-null    object
#  3   DEVELOPMENT STAGE        594 non-null    object
#  4   CONSTRUCTION TYPE        561 non-null    object
#  5   SITE ADDRESS             595 non-null    object
#  6   SITE  COUNCIL DISTRICT   595 non-null    int64
#  7   SITE #                   595 non-null    int64
#  8   SITE COMMUNITY           588 non-null    object
#  9   SITE UNITS               595 non-null    int64
#  10  PROJECT TOTAL UNITS      595 non-null    int64
#  11  HOUSING TYPE             573 non-null    object
#  12  SUPPORTIVE HOUSING       595 non-null    object
#  13  SH UNITS PER SITE        595 non-null    int64
# ...

# %% [markdown]
# ##### Describe

# %%
df_aff_hou_pro.describe()
# Out:
#                 APN  SITE  COUNCIL DISTRICT      SITE #  SITE UNITS  \
# count  5.950000e+02              595.000000  595.000000  595.000000
# mean   4.931625e+09                8.425210    2.072269   54.868908
# std    1.153791e+09                4.631437    2.760317   49.132984
# min    2.103009e+09                1.000000    1.000000    0.000000
# 25%    5.039024e+09                6.000000    1.000000   21.000000
# 50%    5.143020e+09                9.000000    1.000000   49.000000
# 75%    5.511022e+09               13.000000    1.000000   75.500000
# max    7.455014e+09               15.000000   20.000000  438.000000
#
#        PROJECT TOTAL UNITS  SH UNITS PER SITE   LAHD FUNDED      LEVERAGE  \
# count           595.000000         595.000000  5.950000e+02  5.950000e+02
# mean             90.732773          20.235294  4.466108e+06  1.605931e+07
# std              65.384237          32.166210  5.053683e+06  1.321764e+07
# ...

# %% [markdown]
# #### checking individual column for there datatype and unique values in case of categorical values.

# %% [markdown]
# ###### PROJECT TOTAL UNITS

# %%
print(df_aff_hou_pro['PROJECT TOTAL UNITS'])
# Out:
# 0      196
# 1      257
# 2       74
# 3       55
# 4       49
#       ...
# 590     57
# 591    323
# 592     74
# 593     42
# 594     21
# Name: PROJECT TOTAL UNITS, Length: 595, dtype: int64

# %% [markdown]
# ###### HOUSING TYPE

# %%
print(df_aff_hou_pro['HOUSING TYPE'])
# Out:
# 0                             SENIORS
# 1                              FAMILY
# 2                       SPECIAL NEEDS
# 3                             SENIORS
# 4                              FAMILY
#                     ...
# 590                     SPECIAL NEEDS
# 591                            FAMILY
# 592                     SPECIAL NEEDS
# 593                            FAMILY
# 594    LARGE FAMILY / WAIVER REQUIRED
# Name: HOUSING TYPE, Length: 595, dtype: object

# %% [markdown]
# ##### Changing the datatype of Housing type and looking for unique values in it.

# %%
df_aff_hou_pro['HOUSING TYPE'] = df_aff_hou_pro['HOUSING TYPE'].astype(str)
unique_values = df_aff_hou_pro['HOUSING TYPE'].unique()
print(unique_values)
# Out:
# ['SENIORS' 'FAMILY' 'SPECIAL NEEDS' 'nan' 'LARGE FAMILY / WAIVER REQUIRED'
#  'AT-RISK' 'SRO']

# %% [markdown]
# ##### Supportive Housing

# %%
print(df_aff_hou_pro['SUPPORTIVE HOUSING'])
# Out:
# 0       No
# 1       No
# 2      Yes
# 3       No
# 4       No
#       ...
# 590    Yes
# 591     No
# 592    Yes
# 593     No
# 594     No
# Name: SUPPORTIVE HOUSING, Length: 595, dtype: object

# %% [markdown]
# #### changing the datatype of Supportive Housing and looking for unique values in it.

# %%
df_aff_hou_pro['SUPPORTIVE HOUSING'] = df_aff_hou_pro['SUPPORTIVE HOUSING'].astype(str)
unique_values = df_aff_hou_pro['SUPPORTIVE HOUSING'].unique()
print(unique_values)
# Out:
# ['No' 'Yes']

# %% [markdown]
# #### (b-1)  Check for the data types and analyses of df_res_mkt_hel

# %%
df_res_mkt_hel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67573 entries, 0 to 67572
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   serial_number        67573 non-null  object
#  1   activity_date        67573 non-null  object
#  2   facility_name        67573 non-null  object
#  3   score                67573 non-null  int64
#  4   grade                67570 non-null  object
#  5   service_code         67573 non-null  int64
#  6   service_description  67573 non-null  object
#  7   employee_id          67573 non-null  object
#  8   facility_address     67573 non-null  object
#  9   facility_city        67573 non-null  object
#  10  facility_id          67573 non-null  object
#  11  facility_state       67573 non-null  object
#  12  facility_zip         67573 non-null  object
#  13  owner_id             67573 non-null  object
#  14  owner_name           67573 non-null  object
# ...

# %%
df_res_mkt_hel.describe()
# Out:
#               score  service_code  program_element_pe
# count  67573.000000  67573.000000        67573.000000
# mean      93.361890      7.618028         1629.463454
# std        3.982303     51.024028            9.414625
# min       64.000000      1.000000         1610.000000
# 25%       91.000000      1.000000         1631.000000
# 50%       94.000000      1.000000         1632.000000
# 75%       96.000000      1.000000         1635.000000
# max      100.000000    401.000000         1641.000000

# %%
import re

# Extract ZIP code (assuming 5-digit format) from SITE ADDRESS
df_aff_hou_pro['ZIP CODE'] = df_aff_hou_pro['SITE ADDRESS'].apply(lambda x: re.findall(r'\b\d{5}\b', x)[-1] if re.search(r'\b\d{5}\b', x) else None)

# Display the extracted ZIP codes
print(df_aff_hou_pro['ZIP CODE'].head())
# Out:
# 0    90017
# 1    90016
# 2    90011
# 3    90043
# 4    90026
# Name: ZIP CODE, dtype: object
