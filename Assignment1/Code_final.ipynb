# %% [markdown]
# <h1 style="font-size:32px;">Assignment 1: Exploratory and Descriptive Data Analysis</h1>

# %% [markdown]
# <a id="NavBar"></a>
# # For nevigating through notebook
# Q1<br>&nbsp; A)[Reading csv files](#section1(a)) <br>
# &nbsp; B_1)[EDA of df_1](#section1(b-1))<br>
# &nbsp; &nbsp; B-1: [Check if the data types are as expected, else convert them](#sec-1b-1-df_1)<br>
# &nbsp; &nbsp; B-2:[Handeling missing value](#sec-1b-2-df_1)<br>
# &nbsp; &nbsp; B-3:[Handeling unexpected entries](#sec-1b-3-df_1)<br>
# &nbsp; &nbsp; B-4:[Plot some graphs to understand the data](#sec-1b-4-df_1)<br>
# &nbsp; B_2)[EDA of df_2](#section1(b-2))<br>
# &nbsp; &nbsp; B-1: [Check if the data types are as expected, else convert them](#sec-1b-1-df_2)<br>
# &nbsp; &nbsp; B-2:[Handeling missing value](#sec-1b-2-df_2)<br>
# &nbsp; &nbsp; B-3:[Handeling unexpected entries](#sec-1b-3-df_2)<br>
# &nbsp; &nbsp; B-4:[Plot some graphs to understand the data](#sec-1b-4-df_2)<br>
# &nbsp; C)[ Summarize each file by ZIP code using SQL](#section1(c))<br>
# &nbsp; D)[ Join the files using SQL by ZIP code](#section1(d))<br>
# &nbsp; E) [ Formulate and test the hypothesis](#section1(e))<br>
# [Final Result](#Result)<br>
# [Q2](#Q2)<br>
# Source1: Introduction to statistical learning book<br>
# Source2: link to chat done with gpt<a href="https://chatgpt.com/share/e9b34d40-ab44-4d87-b18b-7ed752832485"> source2 </a> <br>
# sourec3: link to NLP series<a href="https://web.stanford.edu/~jurafsky/slp3/"> source3 </a>

# %% [markdown]
# ##### what is supportive housing? : "Supportive housing is a type of housing designed to provide both affordable housing and supportive services to individuals who may need additional help to maintain housing stability and improve their quality of life. It is often targeted at populations who face significant barriers to securing and maintaining housing on their own. This includes people experiencing homelessness, those with chronic health conditions, or individuals with disabilities." --- chatGPT
# ##### Affordable housing : "The housing is typically affordable, meaning that the rent is set at a level that is subsidized or capped to ensure it is within reach for low-income individuals or families."--- chatGPT
#
# <a id="section1(a)"></a>

# %%
import pandas as pd # for reading the csv file
import numpy as np # for numerical python
import matplotlib.pyplot as plt # for ploting the grap
import seaborn as sns # for using better visualization technique
# Out:
# C:\Users\Shivam\anaconda3\lib\site-packages\scipy\__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.25.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
df_1 = pd.read_csv("LAHD_Affordable_Housing_Projects_List__2003_to_Present_.csv") # used pandas to read the csv file and then stored it under df_1
df_2 = pd.read_csv("Restaurant_and_Market_Health_Inspections.csv")# used to read csv file

# %%
df_1.head() # to see top five row of the pd data frame
# Out:
#           APN PROJECT NUMBER                       NAME DEVELOPMENT STAGE  \
# 0  5143020023      02-118256       SAN LUCAS APARTMENTS        In-Service
# 1  5050011005      05-117193     LEEWARD APTS. (SITE 7)        In-Service
# 2  5114014020      14-121652    FLORENCE MILLS (SITE 5)        In-Service
# 3  4012018025          60013  MORGAN PLACE SENIOR APTS.        In-Service
# 4  5153030026          50036             WITMER HEIGHTS        In-Service
#
#   CONSTRUCTION TYPE                                       SITE ADDRESS  \
# 0  NEW CONSTRUCTION               1221 W 7TH ST  Los Angeles, CA 90017
# 1             REHAB            2809 S WEST BLVD  Los Angeles, CA 90016
# 2  NEW CONSTRUCTION  1037 E MARTIN LUTHER KING BLVD  LOS ANGELES, C...
# 3  NEW CONSTRUCTION        7305 S CRENSHAW BLVD  Los Angeles, CA 90043
# 4               NaN             116 S WITMER ST  Los Angeles, CA 90026
#
#    SITE  COUNCIL DISTRICT  SITE #     SITE COMMUNITY  SITE UNITS  ...  \
# 0                       1       1           WESTLAKE         196  ...
# 1                      10       7  CRENSHAW DISTRICT           0  ...
# 2                       9       5            CENTRAL           0  ...
# 3                       8       1          HYDE PARK          55  ...
# 4                      13       1     TEMPLE-BEAUDRY          49  ...
#
#                 MANAGEMENT COMPANY   CONTACT PHONE  \
# 0         GSL PROPERRTY MANAGEMENT             NaN
# 1  ALPHA PROPERTY MANAGEMENT, INC.  (323) 231-4174
# 2   BARKER MANAGEMENT INCORPORATED  (714) 533-3450
# 3                ABODE COMMUNITIES  (213) 225-2772
# 4         THE JOHN STEWART COMPANY  (213) 482-9122
#
#                                                PHOTO   JOBS  \
# 0  click here (http://hcidapp.lacity.org/mpphotos...    NaN
# 1  click here (http://hcidapp.lacity.org/mpphotos...    NaN
# 2  click here (http://hcidapp.lacity.org/mpphotos...  226.0
# 3  click here (http://hcidapp.lacity.org/mpphotos...  110.0
# 4  click here (http://hcidapp.lacity.org/mpphotos...   95.0
#
#                                  PROJECT SUMMARY URL  CONTRACT NUMBERS  \
# 0  click here (http://hcidapp.lacity.org/ahtfRepo...               NaN
# 1  click here (http://hcidapp.lacity.org/ahtfRepo...               NaN
# 2  click here (http://hcidapp.lacity.org/ahtfRepo...          C-129358
# 3  click here (http://hcidapp.lacity.org/ahtfRepo...          C-111486
# 4  click here (http://hcidapp.lacity.org/ahtfRepo...          C-109452
#
#                 DATE STAMP  SITE LONGITUDE  SITE LATITUDE  \
# 0  2024-08-05T00:00:00.000      -118.26584       34.05235
# 1  2024-08-05T00:00:00.000      -118.34182       34.03071
# 2  2024-08-05T00:00:00.000      -118.25740       34.01115
# 3  2024-08-05T00:00:00.000      -118.33139       33.97355
# 4  2024-08-05T00:00:00.000      -118.26086       34.06173
#
#              GPS_COORDS ON MAP
# 0  POINT (-118.26584 34.05235)
# 1  POINT (-118.34182 34.03071)
# 2   POINT (-118.2574 34.01115)
# 3  POINT (-118.33139 33.97355)
# 4  POINT (-118.26086 34.06173)
#
# [5 rows x 31 columns]

# %%
df_2.head()  # to see top five row of the pd data frame
# Out:
#   serial_number           activity_date        facility_name  score grade  \
# 0     DAJ00E07B  12/29/2017 12:00:00 AM  HABITAT COFFEE SHOP     95     A
# 1     DAQOKRFZB  12/29/2017 12:00:00 AM             REILLY'S     92     A
# 2     DASJI4LUR  12/29/2017 12:00:00 AM       STREET CHURROS     93     A
# 3     DA40LU5AT  12/29/2017 12:00:00 AM    TRINITI ECHO PARK     94     A
# 4     DAXV2RMYC  12/29/2017 12:00:00 AM               POLLEN     94     A
#
#    service_code service_description employee_id           facility_address  \
# 0             1  ROUTINE INSPECTION   EE0000923     3708 N EAGLE ROCK BLVD
# 1             1  ROUTINE INSPECTION   EE0000633        100 WORLD WAY # 120
# 2             1  ROUTINE INSPECTION   EE0000835  6801 HOLLYWOOD BLVD # 253
# 3             1  ROUTINE INSPECTION   EE0000923         1814 W SUNSET BLVD
# 4             1  ROUTINE INSPECTION   EE0000923         2100 ECHO PARK AVE
#
#   facility_city facility_id facility_state facility_zip   owner_id  \
# 0   LOS ANGELES   FA0170465             CA        90065  OW0178123
# 1   LOS ANGELES   FA0244690             CA        90045  OW0208441
# 2   LOS ANGELES   FA0224109             CA        90028  OW0228670
# 3   LOS ANGELES   FA0252528             CA   90026-3227  OW0246287
# 4   LOS ANGELES   FA0252789             CA        90026  OW0246479
#
#                   owner_name                         pe_description  \
# 0   GLASSELL COFFEE SHOP LLC  RESTAURANT (0-30) SEATS MODERATE RISK
# 1  AREAS SKYVIEW LAX JV, LLC  RESTAURANT (0-30) SEATS MODERATE RISK
# 2         STREETCHURROS, INC       RESTAURANT (0-30) SEATS LOW RISK
# 3       AMERICAN HOSPITALITY  RESTAURANT (0-30) SEATS MODERATE RISK
# 4    POLLEN AND PASTRY , LLC  RESTAURANT (0-30) SEATS MODERATE RISK
#
#    program_element_pe         program_name program_status  record_id
# 0                1631  HABITAT COFFEE SHOP         ACTIVE  PR0160774
# 1                1631             REILLY'S         ACTIVE  PR0193026
# 2                1630       STREET CHURROS         ACTIVE  PR0179282
# 3                1631    TRINITI ECHO PARK         ACTIVE  PR0201836
# 4                1631               POLLEN         ACTIVE  PR0202148

# %% [markdown]
# <a id="section1(b-1)"></a>
#
# # (b) Performing EDA on df_1 and df_2
# [NavBar](#NavBar)

# %% [markdown]
# ### By now we have stored the two data into df_1 and df_2. Below we will be performimg EDA on this data. In part B main focus will be on preprocessing both the dataframe and ploting some frequency graph at the end. Both the data frames are analysed seprately. Starting with checking the dtypes followed by handling of missing values and than checking for any unexpected entries  in the column.

# %% [markdown]
# ## (b-1) Check for the data types<a id="sec-1b-1-df_1"></a>
# [NavBar](#NavBar)

# %%
df_1.info() #to see Non-null Count and dtypes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 595 entries, 0 to 594
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   APN                      595 non-null    int64
#  1   PROJECT NUMBER           595 non-null    object
#  2   NAME                     595 non-null    object
#  3   DEVELOPMENT STAGE        594 non-null    object
#  4   CONSTRUCTION TYPE        561 non-null    object
#  5   SITE ADDRESS             595 non-null    object
#  6   SITE  COUNCIL DISTRICT   595 non-null    int64
#  7   SITE #                   595 non-null    int64
#  8   SITE COMMUNITY           588 non-null    object
#  9   SITE UNITS               595 non-null    int64
#  10  PROJECT TOTAL UNITS      595 non-null    int64
#  11  HOUSING TYPE             573 non-null    object
#  12  SUPPORTIVE HOUSING       595 non-null    object
#  13  SH UNITS PER SITE        595 non-null    int64
#  14  DATE FUNDED              594 non-null    object
#  15  LAHD FUNDED              595 non-null    float64
#  16  LEVERAGE                 595 non-null    float64
#  17  TAX EXEMPT CONDUIT BOND  595 non-null    int64
#  18  TDC                      595 non-null    float64
#  19  IN-SERVICE DATE          595 non-null    object
#  20  DEVELOPER                569 non-null    object
#  21  MANAGEMENT COMPANY       540 non-null    object
#  22  CONTACT PHONE            511 non-null    object
#  23  PHOTO                    595 non-null    object
#  24  JOBS                     415 non-null    float64
#  25  PROJECT SUMMARY URL      595 non-null    object
#  26  CONTRACT NUMBERS         447 non-null    object
#  27  DATE STAMP               595 non-null    object
#  28  SITE LONGITUDE           595 non-null    float64
#  29  SITE LATITUDE            595 non-null    float64
#  30  GPS_COORDS ON MAP        595 non-null    object
# dtypes: float64(6), int64(7), object(18)
# memory usage: 144.2+ KB

# %% [markdown]
# #### As we can see there are several feature which are not usefull like : photo, urls ,contractor number,owner name, owner id,etc we can remove them before hand. Doing this will reduce a substential amount of efforts without loss in any information centered to our problem. So our first step will be to refine our dataset to only have column that have some potential in contributing to our problem solving.

# %%
df_11 = df_1.drop(columns = ['APN', 'PROJECT NUMBER', 'NAME', 'SITE #','DATE FUNDED','DEVELOPER','MANAGEMENT COMPANY','CONTACT PHONE','PHOTO','JOBS','PROJECT SUMMARY URL','CONTRACT NUMBERS','SITE LONGITUDE','SITE LATITUDE','GPS_COORDS ON MAP','SITE COMMUNITY','DATE STAMP'])
# drops those column from the df_11 dataframe that are written in square brackest

# %%
df_11.head(5)  # to see top five row of the pd data frame
# Out:
#   DEVELOPMENT STAGE CONSTRUCTION TYPE  \
# 0        In-Service  NEW CONSTRUCTION
# 1        In-Service             REHAB
# 2        In-Service  NEW CONSTRUCTION
# 3        In-Service  NEW CONSTRUCTION
# 4        In-Service               NaN
#
#                                         SITE ADDRESS  SITE  COUNCIL DISTRICT  \
# 0               1221 W 7TH ST  Los Angeles, CA 90017                       1
# 1            2809 S WEST BLVD  Los Angeles, CA 90016                      10
# 2  1037 E MARTIN LUTHER KING BLVD  LOS ANGELES, C...                       9
# 3        7305 S CRENSHAW BLVD  Los Angeles, CA 90043                       8
# 4             116 S WITMER ST  Los Angeles, CA 90026                      13
#
#    SITE UNITS  PROJECT TOTAL UNITS   HOUSING TYPE SUPPORTIVE HOUSING  \
# 0         196                  196        SENIORS                 No
# 1           0                  257         FAMILY                 No
# 2           0                   74  SPECIAL NEEDS                Yes
# 3          55                   55        SENIORS                 No
# 4          49                   49         FAMILY                 No
#
#    SH UNITS PER SITE  LAHD FUNDED    LEVERAGE  TAX EXEMPT CONDUIT BOND  \
# 0                  0         0.00         0.0                        0
# 1                  0         0.00   7103994.0                 10208936
# 2                  0   9389115.63  36081992.0                        0
# 3                  0   5281147.00   8428737.0                        0
# 4                  0   2846000.00  10865989.0                        0
#
#            TDC IN-SERVICE DATE
# 0         0.00            2003
# 1  17312930.00            2006
# 2  45471107.63            2021
# 3  13709884.00            2009
# 4  13711989.00            2008

# %%
df_11['HOUSING TYPE'] = df_11['HOUSING TYPE'].astype('string') # changes the dtype to string
unique_values = df_11['HOUSING TYPE'].unique() #store the unique values as string
print(unique_values) #to print the unique_values
# Out:
# <StringArray>
# [                       'SENIORS',                         'FAMILY',
#                   'SPECIAL NEEDS',                             <NA>,
#  'LARGE FAMILY / WAIVER REQUIRED',                        'AT-RISK',
#                             'SRO']
# Length: 7, dtype: string

# %%
df_11['SUPPORTIVE HOUSING'] = df_11['SUPPORTIVE HOUSING'].astype('string')# changes the dtype to string
unique_values = df_11['SUPPORTIVE HOUSING'].unique()#store the unique values as string
print(unique_values)#to print the unique_values
# Out:
# <StringArray>
# ['No', 'Yes']
# Length: 2, dtype: string

# %%
df_11['LAHD FUNDED'] = df_11['LAHD FUNDED'].astype(int) #changes the dtype to int
df_11['LEVERAGE'] = df_11['LEVERAGE'].astype(int) #changes the dtype to int

# %%
df_11.info() #to display non-null count and dtype of individuall column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 595 entries, 0 to 594
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   DEVELOPMENT STAGE        594 non-null    object
#  1   CONSTRUCTION TYPE        561 non-null    object
#  2   SITE ADDRESS             595 non-null    object
#  3   SITE  COUNCIL DISTRICT   595 non-null    int64
#  4   SITE UNITS               595 non-null    int64
#  5   PROJECT TOTAL UNITS      595 non-null    int64
#  6   HOUSING TYPE             573 non-null    string
#  7   SUPPORTIVE HOUSING       595 non-null    string
#  8   SH UNITS PER SITE        595 non-null    int64
#  9   LAHD FUNDED              595 non-null    int32
#  10  LEVERAGE                 595 non-null    int32
#  11  TAX EXEMPT CONDUIT BOND  595 non-null    int64
#  12  TDC                      595 non-null    float64
#  13  IN-SERVICE DATE          595 non-null    object
# dtypes: float64(1), int32(2), int64(5), object(4), string(2)
# memory usage: 60.6+ KB

# %%
df_11.sample(n=10, random_state=1) #to display 10 random row of the data. random state 1 helps to return the same result again.
# Out:
#     DEVELOPMENT STAGE    CONSTRUCTION TYPE  \
# 543        In-Service     NEW CONSTRUCTION
# 528        In-Service     NEW CONSTRUCTION
# 458        In-Service  ACQUISITION + REHAB
# 314        In-Service     NEW CONSTRUCTION
# 462        In-Service                REHAB
# 532        In-Service     NEW CONSTRUCTION
# 245        In-Service                REHAB
# 342        In-Service                  NaN
# 444        In-Service                REHAB
# 0          In-Service     NEW CONSTRUCTION
#
#                                          SITE ADDRESS  SITE  COUNCIL DISTRICT  \
# 543             550 W 127TH ST  Los Angeles, CA 90044                      15
# 528               240 E 6TH ST  Los Angeles, CA 90014                      14
# 458        11301 WILSHIRE BLVD  Los Angeles, CA 90073                      11
# 314      1421 W TEMPLE ST 1-52  Los Angeles, CA 90026                       1
# 462  11301 WILSHIRE BLVD  #207  Los Angeles, CA 90073                      11
# 532                820 S BURLINGTON AVE 1-21 CA 90057                       1
# 245            1206 E 105TH ST  Los Angeles, CA 90002                      15
# 342          4314 W ADAMS BLVD  Los Angeles, CA 90018                      10
# 444             1733 W 58TH ST  Los Angeles, CA 90062                       8
# 0                1221 W 7TH ST  Los Angeles, CA 90017                       1
#
#      SITE UNITS  PROJECT TOTAL UNITS   HOUSING TYPE SUPPORTIVE HOUSING  \
# 543          85                   85  SPECIAL NEEDS                Yes
# 528         102                  102  SPECIAL NEEDS                Yes
# 458          68                   68  SPECIAL NEEDS                Yes
# 314          52                   52         FAMILY                 No
# 462          60                   60        SENIORS                Yes
# 532          21                   21  SPECIAL NEEDS                Yes
# 245           0                  257         FAMILY                 No
# 342          38                   86           <NA>                Yes
# 444           9                  125         FAMILY                 No
# 0           196                  196        SENIORS                 No
#
#      SH UNITS PER SITE  LAHD FUNDED  LEVERAGE  TAX EXEMPT CONDUIT BOND  \
# 543                 84      8900000  22694976                        0
# 528                100      3000000  37140676                        0
# 458                 67     11622000  23102387                  8100000
# 314                  0      3137768  10165531                        0
# 462                 59      8260000  25361269                        0
# 532                 20      1845000   9161655                        0
# 245                  0            0   7103994                 10208936
# 342                 19     12000000  42345241                  5991700
# 444                  0            0   8116043                  6787000
# 0                    0            0         0                        0
#
#             TDC IN-SERVICE DATE
# 543  31594976.0            2018
# 528  40140676.0            2013
# 458  42824387.0            2023
# 314  13303299.0            2007
# 462  33621269.0            2022
# 532  11006655.0            2011
# 245  17312930.0            2006
# 342  60336941.0            2022
# 444  14903043.0            2008
# 0           0.0            2003

# %%
#source-->{3}: NLP series by Standford:1st slide on Regular expression
import re

# Extract ZIP code from SITE ADDRESS
df_11['ZIP CODE'] = df_11['SITE ADDRESS'].apply(lambda x: re.findall(r'\b\d{5}\b', x)[-1] if re.search(r'\b\d{5}\b', x) else None)

# Display the extracted ZIP codes
print(df_11['ZIP CODE'].head())
# Out:
# 0    90017
# 1    90016
# 2    90011
# 3    90043
# 4    90026
# Name: ZIP CODE, dtype: object

# %%
df_11 = df_11.drop(columns = ['SITE ADDRESS']) #drop column named "SITE ADDRESS"

# %%
df_11['ZIP CODE'] = df_11['ZIP CODE'].astype('int') #change the dtype to int
df_11.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 595 entries, 0 to 594
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   DEVELOPMENT STAGE        594 non-null    object
#  1   CONSTRUCTION TYPE        561 non-null    object
#  2   SITE  COUNCIL DISTRICT   595 non-null    int64
#  3   SITE UNITS               595 non-null    int64
#  4   PROJECT TOTAL UNITS      595 non-null    int64
#  5   HOUSING TYPE             573 non-null    string
#  6   SUPPORTIVE HOUSING       595 non-null    string
#  7   SH UNITS PER SITE        595 non-null    int64
#  8   LAHD FUNDED              595 non-null    int32
#  9   LEVERAGE                 595 non-null    int32
#  10  TAX EXEMPT CONDUIT BOND  595 non-null    int64
#  11  TDC                      595 non-null    float64
#  12  IN-SERVICE DATE          595 non-null    object
#  13  ZIP CODE                 595 non-null    int32
# dtypes: float64(1), int32(3), int64(5), object(3), string(2)
# memory usage: 58.2+ KB

# %%
df_11.columns # displays the column of "df_11"
# Out:
# Index(['DEVELOPMENT STAGE', 'CONSTRUCTION TYPE', 'SITE  COUNCIL DISTRICT',
#        'SITE UNITS', 'PROJECT TOTAL UNITS', 'HOUSING TYPE',
#        'SUPPORTIVE HOUSING', 'SH UNITS PER SITE', 'LAHD FUNDED', 'LEVERAGE',
#        'TAX EXEMPT CONDUIT BOND', 'TDC', 'IN-SERVICE DATE', 'ZIP CODE'],
#       dtype='object')

# %% [markdown]
# <a id = "sec-1b-2-df_1"></a>
# ## b2 check for missing values
# [NavBar](#NavBar)

# %%
missing_percentage = df_11.isnull().mean() * 100 #get the percentage of missing value in each column

# Display the result
print(missing_percentage)
# Out:
# DEVELOPMENT STAGE          0.168067
# CONSTRUCTION TYPE          5.714286
# SITE  COUNCIL DISTRICT     0.000000
# SITE UNITS                 0.000000
# PROJECT TOTAL UNITS        0.000000
# HOUSING TYPE               3.697479
# SUPPORTIVE HOUSING         0.000000
# SH UNITS PER SITE          0.000000
# LAHD FUNDED                0.000000
# LEVERAGE                   0.000000
# TAX EXEMPT CONDUIT BOND    0.000000
# TDC                        0.000000
# IN-SERVICE DATE            0.000000
# ZIP CODE                   0.000000
# dtype: float64

# %%
# Calculate the percentage of zero values in each column
zero_percentage = (df_11 == 0).mean() * 100

# Display the result
print(zero_percentage)
# Out:
# DEVELOPMENT STAGE           0.000000
# CONSTRUCTION TYPE           0.000000
# SITE  COUNCIL DISTRICT      0.000000
# SITE UNITS                 10.924370
# PROJECT TOTAL UNITS         0.000000
# HOUSING TYPE                0.000000
# SUPPORTIVE HOUSING          0.000000
# SH UNITS PER SITE          59.327731
# LAHD FUNDED                26.722689
# LEVERAGE                   10.588235
# TAX EXEMPT CONDUIT BOND    63.361345
# TDC                         2.184874
# IN-SERVICE DATE             0.000000
# ZIP CODE                    0.000000
# dtype: float64

# %% [markdown]
# ### as the percentage of missing values is nearly 5 so we will not lose much info. Hence we can remove the rows with null values.

# %%
df_11 = df_11.dropna() #drop all the rows with any null value

# %%
df_11.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 560 entries, 0 to 594
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   DEVELOPMENT STAGE        560 non-null    object
#  1   CONSTRUCTION TYPE        560 non-null    object
#  2   SITE  COUNCIL DISTRICT   560 non-null    int64
#  3   SITE UNITS               560 non-null    int64
#  4   PROJECT TOTAL UNITS      560 non-null    int64
#  5   HOUSING TYPE             560 non-null    string
#  6   SUPPORTIVE HOUSING       560 non-null    string
#  7   SH UNITS PER SITE        560 non-null    int64
#  8   LAHD FUNDED              560 non-null    int32
#  9   LEVERAGE                 560 non-null    int32
#  10  TAX EXEMPT CONDUIT BOND  560 non-null    int64
#  11  TDC                      560 non-null    float64
#  12  IN-SERVICE DATE          560 non-null    object
#  13  ZIP CODE                 560 non-null    int32
# dtypes: float64(1), int32(3), int64(5), object(3), string(2)
# memory usage: 59.1+ KB

# %% [markdown]
# <a id="sec-1b-3-df_1"></a>
# ## b-3 check for unexplected values in column
# [NavBar](#NavBar)

# %%
# Check for non-numeric values in site council district
non_numeric_districts = df_11[pd.to_numeric(df_11['SITE  COUNCIL DISTRICT'], errors='coerce').isna()] # The 'errors='coerce'' parameter replaces values that cannot be converted with NaN (Not a Number).then isna identifes those vaues
print("Non-numeric entries in SITE COUNCIL DISTRICT:\n", non_numeric_districts['SITE  COUNCIL DISTRICT'].unique()) #prints the non-numeric values
# Out:
# Non-numeric entries in SITE COUNCIL DISTRICT:
#  []

# %%
invalid_units = df_11[(df_11['SITE UNITS'] < 0) | (df_11['PROJECT TOTAL UNITS'] <= 0)]
# Check for negative or zero values (units shouldn't be negative or zero)
print("Invalid entries in SITE UNITS or PROJECT TOTAL UNITS:\n", invalid_units[['SITE UNITS', 'PROJECT TOTAL UNITS']])
# Out:
# Invalid entries in SITE UNITS or PROJECT TOTAL UNITS:
#  Empty DataFrame
# Columns: [SITE UNITS, PROJECT TOTAL UNITS]
# Index: []

# %%
# Expected values (example: 'Yes', 'No')
expected_supportive_housing = ['Yes', 'No']

# Check for unexpected entries
unexpected_supportive_housing = df_11[~df_11['SUPPORTIVE HOUSING'].isin(expected_supportive_housing)]
#The `isin()` method checks if each value in the 'SUPPORTIVE HOUSING' column is present in the `expected_supportive_housing` list.
# The `~` operator is used to invert the boolean series, so it selects rows where 'SUPPORTIVE HOUSING' values are not in the list.
print("Unexpected entries in SUPPORTIVE HOUSING:\n", unexpected_supportive_housing['SUPPORTIVE HOUSING'].unique()) #to print the unexpected value
# Out:
# Unexpected entries in SUPPORTIVE HOUSING:
#  <StringArray>
# []
# Length: 0, dtype: string

# %%
invalid_sh_units = df_11[df_11['SH UNITS PER SITE'] < 0] # Check for negative values
print("Invalid entries in SH UNITS PER SITE:\n", invalid_sh_units['SH UNITS PER SITE']) #print the negative values
# Out:
# Invalid entries in SH UNITS PER SITE:
#  Series([], Name: SH UNITS PER SITE, dtype: int64)

# %%
df_11['IN-SERVICE DATE'] = pd.to_datetime(df_11['IN-SERVICE DATE'], errors='coerce')# Check if the date column is in a valid date format
invalid_dates = df_11[df_11['IN-SERVICE DATE'].isna()]# Check for invalid dates
print("Invalid entries in IN-SERVICE DATE:\n", invalid_dates['IN-SERVICE DATE'])#prints the invalid dates
# Out:
# Invalid entries in IN-SERVICE DATE:
#  14    NaT
# 39    NaT
# 40    NaT
# 64    NaT
# 69    NaT
# 100   NaT
# 110   NaT
# 112   NaT
# 157   NaT
# 166   NaT
# 182   NaT
# 183   NaT
# 194   NaT
# 195   NaT
# 201   NaT
# 211   NaT
# 219   NaT
# 224   NaT
# 228   NaT
# 230   NaT
# 231   NaT
# 240   NaT
# 243   NaT
# 255   NaT
# 259   NaT
# 261   NaT
# 283   NaT
# 284   NaT
# 292   NaT
# 293   NaT
# 310   NaT
# 320   NaT
# 336   NaT
# 340   NaT
# 369   NaT
# 378   NaT
# 393   NaT
# 396   NaT
# 400   NaT
# 411   NaT
# 412   NaT
# 432   NaT
# 434   NaT
# 439   NaT
# 461   NaT
# 467   NaT
# 472   NaT
# 491   NaT
# 500   NaT
# 506   NaT
# 530   NaT
# 549   NaT
# 556   NaT
# 589   NaT
# Name: IN-SERVICE DATE, dtype: datetime64[ns]

# %% [markdown]
# ### here the column of of time is not much importance to us. so even if it has some NaT value we will ignore it. For other we have not seen any unexpected value

# %%
non_numeric_zipcodes = df_11[pd.to_numeric(df_11['ZIP CODE'], errors='coerce').isna()]# Check for non-numeric or invalid ZIP codes
print("Non-numeric entries in ZIP CODE:\n", non_numeric_zipcodes['ZIP CODE'].unique())
invalid_zipcodes = df_11[df_11['ZIP CODE'].astype(str).str.len() != 5]# check for ZIP codes with unexpected lengths
print("Invalid ZIP CODES:\n", invalid_zipcodes['ZIP CODE'].unique())
# Out:
# Non-numeric entries in ZIP CODE:
#  []
# Invalid ZIP CODES:
#  []

# %% [markdown]
# <a id="sec-1b-4-df_1"></a>
# ## b-4 Ploting Graph to understand the data
# [NavBar](#NavBar)

# %%
# Count the occurrences of each unique value in the 'DEVELOPMENT STAGE' column and create a bar plot.
df_11['DEVELOPMENT STAGE'].value_counts().plot(kind='bar', figsize=(8, 6))  # Plot a bar chart of development stages with specified figure size.
plt.title('Development Stage Distribution') # Set the title of the plot to 'Development Stage Distribution'.
plt.xlabel('Development Stage') # Label the x-axis as 'Development Stage'. 
plt.ylabel('Frequency') # Label the y-axis as 'Frequency'. 
plt.show()# Display the plot.

# %%
df_11['CONSTRUCTION TYPE'].value_counts().plot(kind='bar', figsize=(8, 6))
plt.title('Construction Type Distribution')
plt.xlabel('Construction Type')
plt.ylabel('Frequency')
plt.show()

# %%
df_11['SITE  COUNCIL DISTRICT'].value_counts().plot(kind='bar', figsize=(8, 6))
plt.title('Site Council District Distribution')
plt.xlabel('Council District')
plt.ylabel('Frequency')
plt.show()

# %%
df_11['SITE UNITS'].plot(kind='hist', bins=30, edgecolor='black', figsize=(8, 6))# in addition to above this also set the edge color to black
plt.title('Distribution of Site Units')
plt.xlabel('Site Units')
plt.ylabel('Frequency')
plt.show()

df_11['PROJECT TOTAL UNITS'].plot(kind='hist', bins=30, edgecolor='black', figsize=(8, 6))
plt.title('Distribution of Project Total Units')
plt.xlabel('Project Total Units')
plt.ylabel('Frequency')
plt.show()

# %%
df_11[['SITE UNITS', 'PROJECT TOTAL UNITS']].plot(kind='box', figsize=(8, 6))  # Create a box plot for 'SITE UNITS' and 'PROJECT TOTAL UNITS' with a figure size of 8x6.
plt.title('Box Plot of Units')  # Set the title of the plot to 'Box Plot of Units'.
plt.show()  # Display the plot.

# %%
df_11['HOUSING TYPE'].value_counts().plot(kind='pie', autopct='%1.1f%%', figsize=(8, 6))  # Create a pie chart of 'HOUSING TYPE' with percentage labels and a figure size of 8x6.
plt.title('Housing Type Distribution')  # Set the title of the plot to 'Housing Type Distribution'.
plt.ylabel('')  # Remove the y-axis label for the pie chart.
plt.show()  # Display the pie chart.

# %%
df_11['SUPPORTIVE HOUSING'].value_counts().plot(kind='bar', figsize=(8, 6))  # Create a bar plot of 'SUPPORTIVE HOUSING' values with a figure size of 8x6.
plt.title('Supportive Housing (Yes/No)')  # Set the title of the plot to 'Supportive Housing (Yes/No)'.
plt.xlabel('Supportive Housing')  # Label the x-axis as 'Supportive Housing'.
plt.ylabel('Frequency')  # Label the y-axis as 'Frequency'.
plt.show()  # Display the bar plot.

# %%
plt.figure(figsize=(10, 6))  # Set the figure size to 10x6 for the scatter plot.
plt.scatter(df_11['LAHD FUNDED'], df_11['SH UNITS PER SITE'], color='blue', alpha=0.6)  # Create a scatter plot with 'LAHD FUNDED' on the x-axis and 'SH UNITS PER SITE' on the y-axis, with blue points and transparency set to 0.6.
# Adding labels and title
plt.xlabel('LAHD FUNDED ($)')  # Label the x-axis as 'LAHD FUNDED ($)'.
plt.ylabel('SH UNITS PER SITE')  # Label the y-axis as 'SH UNITS PER SITE'.
plt.title('Scatter Plot Between LAHD FUNDED and SH UNITS PER SITE')  # Set the title of the scatter plot.
# Display the plot
plt.show()

# %%
# Grouping data by 'ZIP CODE' and summing the values
aggregated_data = df_11.groupby('ZIP CODE').sum()  # Aggregate the data by summing up values for each ZIP CODE.

# Generate numerical indices for the x-axis
x_indices = range(len(aggregated_data))  # Create a range of numerical indices based on the number of aggregated data rows.

# Now plot the aggregated data using numerical indices instead of ZIP codes
plt.figure(figsize=(10, 6))  # Set the figure size to 10x6 for the bar chart.
plt.bar(x_indices, aggregated_data['SITE UNITS'], label='SITE UNITS')  # Create a bar plot for 'SITE UNITS' with numerical indices on the x-axis.
plt.bar(x_indices, aggregated_data['SH UNITS PER SITE'], label='SH UNITS PER SITE', bottom=aggregated_data['SITE UNITS'])  # Create a stacked bar plot for 'SH UNITS PER SITE', stacked on top of 'SITE UNITS'.

# Adding labels and title
plt.xlabel('Index')  # Label the x-axis as 'Index'.
plt.ylabel('Total Units')  # Label the y-axis as 'Total Units'.
plt.title('Bar Chart of Total Units by ZIP CODE (Numerical Index)')  # Set the title of the bar chart.
plt.legend()  # Add a legend to differentiate between 'SITE UNITS' and 'SH UNITS PER SITE'.

# Display the plot
plt.show()  # Show the bar chart.

# %%
# Selecting relevant columns for the pairplot
selected_columns = ['SITE  COUNCIL DISTRICT',  # List of columns to include in the pairplot.
       'SITE UNITS', 'PROJECT TOTAL UNITS', 'HOUSING TYPE',
       'SUPPORTIVE HOUSING', 'SH UNITS PER SITE', 'LAHD FUNDED', 'LEVERAGE',
       'TAX EXEMPT CONDUIT BOND']
sns.pairplot(df_11[selected_columns])  # Generate a pairplot to visualize relationships between the selected columns.
plt.suptitle('Pair Plot Showing Relationships Between Selected Columns', y=1.05)  # Set the title of the plot with a slight vertical offset.

# Display the plot
plt.show()

# %% [markdown]
# <a id="section1(b-2)"></a>
# ## EDA on Dataset df_2
# [NavBar](#NavBar)

# %%
df_2.head()
# Out:
#   serial_number           activity_date        facility_name  score grade  \
# 0     DAJ00E07B  12/29/2017 12:00:00 AM  HABITAT COFFEE SHOP     95     A
# 1     DAQOKRFZB  12/29/2017 12:00:00 AM             REILLY'S     92     A
# 2     DASJI4LUR  12/29/2017 12:00:00 AM       STREET CHURROS     93     A
# 3     DA40LU5AT  12/29/2017 12:00:00 AM    TRINITI ECHO PARK     94     A
# 4     DAXV2RMYC  12/29/2017 12:00:00 AM               POLLEN     94     A
#
#    service_code service_description employee_id           facility_address  \
# 0             1  ROUTINE INSPECTION   EE0000923     3708 N EAGLE ROCK BLVD
# 1             1  ROUTINE INSPECTION   EE0000633        100 WORLD WAY # 120
# 2             1  ROUTINE INSPECTION   EE0000835  6801 HOLLYWOOD BLVD # 253
# 3             1  ROUTINE INSPECTION   EE0000923         1814 W SUNSET BLVD
# 4             1  ROUTINE INSPECTION   EE0000923         2100 ECHO PARK AVE
#
#   facility_city facility_id facility_state facility_zip   owner_id  \
# 0   LOS ANGELES   FA0170465             CA        90065  OW0178123
# 1   LOS ANGELES   FA0244690             CA        90045  OW0208441
# 2   LOS ANGELES   FA0224109             CA        90028  OW0228670
# 3   LOS ANGELES   FA0252528             CA   90026-3227  OW0246287
# 4   LOS ANGELES   FA0252789             CA        90026  OW0246479
#
#                   owner_name                         pe_description  \
# 0   GLASSELL COFFEE SHOP LLC  RESTAURANT (0-30) SEATS MODERATE RISK
# 1  AREAS SKYVIEW LAX JV, LLC  RESTAURANT (0-30) SEATS MODERATE RISK
# 2         STREETCHURROS, INC       RESTAURANT (0-30) SEATS LOW RISK
# 3       AMERICAN HOSPITALITY  RESTAURANT (0-30) SEATS MODERATE RISK
# 4    POLLEN AND PASTRY , LLC  RESTAURANT (0-30) SEATS MODERATE RISK
#
#    program_element_pe         program_name program_status  record_id
# 0                1631  HABITAT COFFEE SHOP         ACTIVE  PR0160774
# 1                1631             REILLY'S         ACTIVE  PR0193026
# 2                1630       STREET CHURROS         ACTIVE  PR0179282
# 3                1631    TRINITI ECHO PARK         ACTIVE  PR0201836
# 4                1631               POLLEN         ACTIVE  PR0202148

# %%
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67573 entries, 0 to 67572
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   serial_number        67573 non-null  object
#  1   activity_date        67573 non-null  object
#  2   facility_name        67573 non-null  object
#  3   score                67573 non-null  int64
#  4   grade                67570 non-null  object
#  5   service_code         67573 non-null  int64
#  6   service_description  67573 non-null  object
#  7   employee_id          67573 non-null  object
#  8   facility_address     67573 non-null  object
#  9   facility_city        67573 non-null  object
#  10  facility_id          67573 non-null  object
#  11  facility_state       67573 non-null  object
#  12  facility_zip         67573 non-null  object
#  13  owner_id             67573 non-null  object
#  14  owner_name           67573 non-null  object
#  15  pe_description       67573 non-null  object
#  16  program_element_pe   67573 non-null  int64
#  17  program_name         67544 non-null  object
#  18  program_status       67573 non-null  object
#  19  record_id            67573 non-null  object
# dtypes: int64(3), object(17)
# memory usage: 10.3+ MB

# %%
df_2.columns
# Out:
# Index(['serial_number', 'activity_date', 'facility_name', 'score', 'grade',
#        'service_code', 'service_description', 'employee_id',
#        'facility_address', 'facility_city', 'facility_id', 'facility_state',
#        'facility_zip', 'owner_id', 'owner_name', 'pe_description',
#        'program_element_pe', 'program_name', 'program_status', 'record_id'],
#       dtype='object')

# %%
df_21 = df_2[['facility_name', 'score', 'grade',
       'service_code', 'service_description', 'employee_id',
       'facility_zip','pe_description',
       'program_element_pe', 'program_name', 'program_status']]# selecting column for making a new dataframe

# %%
df_21.head(10)
# Out:
#          facility_name  score grade  service_code service_description  \
# 0  HABITAT COFFEE SHOP     95     A             1  ROUTINE INSPECTION
# 1             REILLY'S     92     A             1  ROUTINE INSPECTION
# 2       STREET CHURROS     93     A             1  ROUTINE INSPECTION
# 3    TRINITI ECHO PARK     94     A             1  ROUTINE INSPECTION
# 4               POLLEN     94     A             1  ROUTINE INSPECTION
# 5       THE SPOT GRILL     93     A             1  ROUTINE INSPECTION
# 6     7 ELEVEN #37215A     95     A             1  ROUTINE INSPECTION
# 7                  CPK     91     A             1  ROUTINE INSPECTION
# 8             PHO LALA     95     A             1  ROUTINE INSPECTION
# 9           ABC DONUTS     91     A             1  ROUTINE INSPECTION
#
#   employee_id facility_zip                         pe_description  \
# 0   EE0000923        90065  RESTAURANT (0-30) SEATS MODERATE RISK
# 1   EE0000633        90045  RESTAURANT (0-30) SEATS MODERATE RISK
# 2   EE0000835        90028       RESTAURANT (0-30) SEATS LOW RISK
# 3   EE0000923   90026-3227  RESTAURANT (0-30) SEATS MODERATE RISK
# 4   EE0000923        90026  RESTAURANT (0-30) SEATS MODERATE RISK
# 5   EE0000727        90034      RESTAURANT (0-30) SEATS HIGH RISK
# 6   EE0000839   90043-4706   FOOD MKT RETAIL (2,000+ SF) LOW RISK
# 7   EE0000633        90045    RESTAURANT (61-150) SEATS HIGH RISK
# 8   EE0000699        90020      RESTAURANT (0-30) SEATS HIGH RISK
# 9   EE0000923        90065  RESTAURANT (0-30) SEATS MODERATE RISK
#
#    program_element_pe         program_name program_status
# 0                1631  HABITAT COFFEE SHOP         ACTIVE
# 1                1631             REILLY'S         ACTIVE
# 2                1630       STREET CHURROS         ACTIVE
# 3                1631    TRINITI ECHO PARK         ACTIVE
# 4                1631               POLLEN         ACTIVE
# 5                1632       THE SPOT GRILL       INACTIVE
# 6                1613     7 ELEVEN #37215A         ACTIVE
# 7                1638                  CPK         ACTIVE
# 8                1632             PHO LALA         ACTIVE
# 9                1631           ABC DONUTS         ACTIVE

# %%
df_21.columns
# Out:
# Index(['facility_name', 'score', 'grade', 'service_code',
#        'service_description', 'employee_id', 'facility_zip', 'pe_description',
#        'program_element_pe', 'program_name', 'program_status'],
#       dtype='object')

# %%
# Apply the str.slice() to extract the first 6 characters of each ZIP CODE
df_21['ZIP CODE'] = df_21['facility_zip'].astype(str).str.slice(0, 5)

# Display the updated DataFrame to confirm the changes
print(df_21[['ZIP CODE']].head())
# Out:
#   ZIP CODE
# 0    90065
# 1    90045
# 2    90028
# 3    90026
# 4    90026
# C:\Users\Shivam\AppData\Local\Temp\ipykernel_18224\1628172466.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_21['ZIP CODE'] = df_21['facility_zip'].astype(str).str.slice(0, 5)

# %%
df_21 = df_21.drop('facility_zip', axis=1)  # Drop the 'facility_zip' column from the DataFrame df_21.

# %% [markdown]
# <a id="sec-1b-1-df_2"></a>
# ## Check for data type
# [NavBar](#NavBar)

# %%
df_21.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67573 entries, 0 to 67572
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   facility_name        67573 non-null  object
#  1   score                67573 non-null  int64
#  2   grade                67570 non-null  object
#  3   service_code         67573 non-null  int64
#  4   service_description  67573 non-null  object
#  5   employee_id          67573 non-null  object
#  6   pe_description       67573 non-null  object
#  7   program_element_pe   67573 non-null  int64
#  8   program_name         67544 non-null  object
#  9   program_status       67573 non-null  object
#  10  ZIP CODE             67573 non-null  object
# dtypes: int64(3), object(8)
# memory usage: 5.7+ MB

# %%
df_21.columns
# Out:
# Index(['facility_name', 'score', 'grade', 'service_code',
#        'service_description', 'employee_id', 'pe_description',
#        'program_element_pe', 'program_name', 'program_status', 'ZIP CODE'],
#       dtype='object')

# %%
df_21.dtypes
# Out:
# facility_name          object
# score                   int64
# grade                  object
# service_code            int64
# service_description    object
# employee_id            object
# pe_description         object
# program_element_pe      int64
# program_name           object
# program_status         object
# ZIP CODE               object
# dtype: object

# %%
unique_values = {}  # Initialize an empty dictionary to store unique values for each column.

for column in df_21.columns:  # Iterate over each column in the DataFrame df_21.
    unique_values[column] = df_21[column].unique()  # Store unique values of the current column in the dictionary.

for column, values in unique_values.items():  # Iterate over the dictionary items (column names and their unique values).
    print(f"Unique values in column '{column}':")  # Print the name of the column.
    print(values)  # Print the unique values for the column.
    print("\n")  # Print a newline for better readability between columns.
# Out:
# Unique values in column 'facility_name':
# ['HABITAT COFFEE SHOP' "REILLY'S" 'STREET CHURROS' ... 'FIN-MELROSE'
#  'MEDIDATE COFFEE' 'CAFE SPROUTS']
#
#
# Unique values in column 'score':
# [ 95  92  93  94  91  97  90  98  85  82  96 100  84  86  99  80  83  81
#   78  73  87  72  77  88  76  74  75  89  70  71  79  65  64  68  67  66]
#
#
# Unique values in column 'grade':
# ['A' 'B' 'C' ' ' nan]
#
#
# Unique values in column 'service_code':
# [  1 401]
#
#
# Unique values in column 'service_description':
# ['ROUTINE INSPECTION' 'OWNER INITIATED ROUTINE INSPECT.']
#
#
# Unique values in column 'employee_id':
# ['EE0000923' 'EE0000633' 'EE0000835' 'EE0000727' 'EE0000839' 'EE0000699'
#  'EE0000581' 'EE0000857' 'EE0000854' 'EE0000729' 'EE0000338' 'EE0000117'
#  'EE0000951' 'EE0000366' 'EE0000659' 'EE0000884' 'EE0000224' 'EE0000721'
#  'EE0000905' 'EE0000122' 'EE0000709' 'EE0000955' 'EE0000740' 'EE0000697'
#  'EE0000894' 'EE0000997' 'EE0000822' 'EE0000733' 'EE0000162' 'EE0000838'
#  'EE0000904' 'EE0000869' 'EE0000605' 'EE0001049' 'EE0001025' 'EE0000911'
#  'EE0000836' 'EE0000006' 'EE0000195' 'EE0000557' 'EE0001003' 'EE0001048'
#  'EE0000043' 'EE0000492' 'EE0000957' 'EE0000828' 'EE0000531' 'EE0000946'
#  'EE0000953' 'EE0000746' 'EE0000723' 'EE0000198' 'EE0000924' 'EE0000506'
#  'EE0001026' 'EE0000521' 'EE0000468' 'EE0000799' 'EE0000375' 'EE0000015'
#  'EE0000059' 'EE0000724' 'EE0000798' 'EE0000360' 'EE0001058' 'EE0000684'
#  'EE0000399' 'EE0000420' 'EE0000144' 'EE0000800' 'EE0000262' 'EE0000707'
#  'EE0001075' 'EE0000725' 'EE0000925' 'EE0000912' 'EE0000523' 'EE0000950'
#  'EE0000853' 'EE0000593' 'EE0000726' 'EE0000728' 'EE0000722' 'EE0000025'
#  'EE0000147' 'EE0000249' 'EE0000495' 'EE0001002' 'EE0001014' 'EE0000703'
#  'EE0000660' 'EE0000855' 'EE0001021' 'EE0000063' 'EE0000874' 'EE0000176'
#  'EE0000594' 'EE0000424' 'EE0000064' 'EE0001072' 'EE0000284' 'EE0000776'
#  'EE0000751' 'EE0000606' 'EE0000183' 'EE0000426' 'EE0000160' 'EE0000434'
#  'EE0001064' 'EE0000720' 'EE0001073' 'EE0000820' 'EE0000927' 'EE0000513'
#  'EE0001006' 'EE0000846' 'EE0000093' 'EE0000893' 'EE0000528' 'EE0000629'
#  'EE0000871' 'EE0000037' 'EE0000691' 'EE0000958' 'EE0000140' 'EE0000719'
#  'EE0000246' 'EE0000732' 'EE0000745' 'EE0000255' 'EE0000883' 'EE0000259'
#  'EE0000476' 'EE0000718' 'EE0000741' 'EE0000965' 'EE0001004' 'EE0000715'
#  'EE0000516' 'EE0000099' 'EE0001005' 'EE0001045' 'EE0000314']
#
#
# Unique values in column 'pe_description':
# ['RESTAURANT (0-30) SEATS MODERATE RISK'
#  'RESTAURANT (0-30) SEATS LOW RISK' 'RESTAURANT (0-30) SEATS HIGH RISK'
#  'FOOD MKT RETAIL (2,000+ SF) LOW RISK'
#  'RESTAURANT (61-150) SEATS HIGH RISK'
#  'RESTAURANT (31-60) SEATS HIGH RISK'
#  'RESTAURANT (61-150) SEATS MODERATE RISK'
#  'RESTAURANT (151 + ) SEATS HIGH RISK'
#  'RESTAURANT (31-60) SEATS MODERATE RISK'
#  'FOOD MKT RETAIL (1-1,999 SF) HIGH RISK'
#  'RESTAURANT (151 + ) SEATS MODERATE RISK'
#  'FOOD MKT RETAIL (2,000+ SF) MODERATE RISK'
#  'RESTAURANT (31-60) SEATS LOW RISK' 'RESTAURANT (151 + ) SEATS LOW RISK'
#  'FOOD MKT RETAIL (2,000+ SF) HIGH RISK'
#  'FOOD MKT RETAIL (1-1,999 SF) LOW RISK'
#  'FOOD MKT RETAIL (1-1,999 SF) MODERATE RISK'
#  'RESTAURANT (61-150) SEATS LOW RISK'
#  'FOOD PROCESSING WHOLESALE (2,000-5,999 SF)'
#  'FOOD MKT RETAIL (25-1,999 SF) HIGH RISK'
#  'LIC HTH CARE FOOD FAC (4000-9999 SF)HIGH RISK'
#  'FOOD MKT RETAIL (25-1,999 SF) MODERATE RISK' 'FOOD MARKET WHOLESALE'
#  'CATERER (0-999 SQ. FT.)' 'FOOD MKT RETAIL (25-1,999 SF) LOW RISK'
#  'LIC HTH CARE FOOD FAC (2000-3999 SF)HIGH RISK' 'SENIOR FEEDING SITE'
#  'PRIVATE SCHOOL CAFETERIA' 'WHOLESALE FOOD COMPLEX'
#  'FOOD WAREHOUSE (1-4,999) SQ. FT.']
#
#
# Unique values in column 'program_element_pe':
# [1631 1630 1632 1613 1638 1635 1637 1641 1634 1612 1640 1614 1633 1639
#  1615 1610 1611 1636]
#
#
# Unique values in column 'program_name':
# ['HABITAT COFFEE SHOP' "REILLY'S" 'STREET CHURROS' ...
#  'HALL OF JUSTICE - CAFETERIA' 'FIN-MELROSE' 'MEDIDATE COFFEE']
#
#
# Unique values in column 'program_status':
# ['ACTIVE' 'INACTIVE']
#
#
# Unique values in column 'ZIP CODE':
# ['90065' '90045' '90028' '90026' '90034' '90043' '90020' '91604' '90027'
#  '90006' '90010' '90064' '90004' '90046' '90005' '90015' '90048' '90023'
#  '90057' '90047' '90039' '90042' '90012' '90062' '90035' '90071' '90013'
#  '90017' '90021' '90033' '90070' '90291' '90068' '90031' '90041' '90014'
#  '90036' '90024' '90008' '91367' '90022' '90037' '90001' '90061' '90044'
#  '90063' '90011' '90019' '90066' '90038' '90016' '90049' '90058' '90059'
#  '90025' '91324' '90069' '90007' '90067' '90211' '90002' '90018' '90003'
#  '90089' '90032' '90029' '90077' '90056' '90040' '91325' '91505' '90232'
#  '90230' '90094' '90095' '90103' '92880' '90054' '91326' '90292' '90052'
#  '90921' '90220' '90723' '90293' '90079' '90051' '91602' '91307' '91006'
#  '90030' '90222' '90272' '91340' '91601' '90201' '90053' '90255' '91401']

# %%
df_21['ZIP CODE'] = df_21['ZIP CODE'].astype(int)
df_21['program_status'] = df_21['program_status'].astype(str)

# %%
# Number of unique values in the 'facility_name' column
num_unique_facility_names = df_21.nunique()

print(f"Number of unique facility names: {num_unique_facility_names}")
# Out:
# Number of unique facility names: facility_name          12069
# score                     36
# grade                      4
# service_code               2
# service_description        2
# employee_id              143
# pe_description            30
# program_element_pe        18
# program_name           12928
# program_status             2
# ZIP CODE                  99
# dtype: int64

# %% [markdown]
# <a id="sec-1b-2-df_2"></a>
# ## B2 check for missing values
# [NavBar](#NavBar)

# %%
missing_percentage = df_21.isnull().mean() * 100

# Display the result
print(missing_percentage)
# Out:
# facility_name          0.000000
# score                  0.000000
# grade                  0.004440
# service_code           0.000000
# service_description    0.000000
# employee_id            0.000000
# pe_description         0.000000
# program_element_pe     0.000000
# program_name           0.042917
# program_status         0.000000
# ZIP CODE               0.000000
# dtype: float64

# %%
# Calculate the percentage of zero values in each column
zero_percentage = (df_21 == 0).mean() * 100

# Display the result
print(zero_percentage)
# Out:
# facility_name          0.0
# score                  0.0
# grade                  0.0
# service_code           0.0
# service_description    0.0
# employee_id            0.0
# pe_description         0.0
# program_element_pe     0.0
# program_name           0.0
# program_status         0.0
# ZIP CODE               0.0
# dtype: float64

# %%
df_21 = df_21.dropna()

# %%
df_21.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 67541 entries, 0 to 67572
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   facility_name        67541 non-null  object
#  1   score                67541 non-null  int64
#  2   grade                67541 non-null  object
#  3   service_code         67541 non-null  int64
#  4   service_description  67541 non-null  object
#  5   employee_id          67541 non-null  object
#  6   pe_description       67541 non-null  object
#  7   program_element_pe   67541 non-null  int64
#  8   program_name         67541 non-null  object
#  9   program_status       67541 non-null  object
#  10  ZIP CODE             67541 non-null  int32
# dtypes: int32(1), int64(3), object(7)
# memory usage: 5.9+ MB

# %% [markdown]
# <a id="sec-1b-3-df_2"></a>
# ## Check for unexpected values
# [NavBar](#NavBar)

# %%
#sorce-->{3}: NLP lecture by standford. 1st lecture of this serie has all understanding of regular expression which was used in bellow code.

import re

# Define a function to check for unexpected values
def check_unexpected_values(df, column, pattern=None):
    # Convert column to string if pattern is provided
    if pattern:
        df[column] = df[column].astype(str)
        # Check for values that do not match the expected pattern
        unexpected_values = df[~df[column].apply(lambda x: bool(pattern.match(x)))]
    else:
        # Convert to string and check for empty strings or NaN values
        df[column] = df[column].astype(str)
        unexpected_values = df[df[column].str.strip().eq('') | df[column].isna()]
    
    return unexpected_values

# Define patterns for columns where a specific format is expected
patterns = {
    'facility_name': re.compile(r'^[\w\s\W]+$'),  # Letters, digits, spaces, and special characters
    'score': re.compile(r'^\d+(\.\d+)?$'),  # Numeric values (integers or decimals)
    'grade': re.compile(r'^[A-F]$'),  # Letter grades (A-F)
    'service_code': re.compile(r'^[A-Z0-9]+$'),  # Alphanumeric codes
    'service_description': None,  # No specific pattern, just check for empty strings and NaNs
    'employee_id': re.compile(r'^EE\d{7}$'),  # Numeric employee IDs
    'pe_description': None,  # No specific pattern, just check for empty strings and NaNs
    'program_element_pe': None,  # No specific pattern, just check for empty strings and NaNs
    'program_name': None,  # No specific pattern, just check for empty strings and NaNs
    'program_status': re.compile(r'^[A-Za-z\s]+$'),  # Only letters and spaces
    'ZIP CODE': re.compile(r'^\d{5}(-\d{4})?$')  # Valid ZIP or ZIP+4 format
}

# Check unexpected values for each column
for column in df_21.columns:  # Iterate over each column in the DataFrame df_21.
    pattern = patterns.get(column)  # Retrieve the pattern associated with the current column from the patterns dictionary.
    unexpected_values = check_unexpected_values(df_21, column, pattern)  # Check for unexpected values in the column using the specified pattern.
    
    if not unexpected_values.empty:  # If there are unexpected values in the column (i.e., the result is not empty).
        print(f"Unexpected values in column '{column}':")  # Print a message indicating there are unexpected values in the column.
        print(unexpected_values)  # Print the unexpected values.
        print("\n")  # Print a newline for better readability between columns.
    else:  # If there are no unexpected values in the column.
        print(f"No unexpected values in column '{column}'.")  # Print a message indicating there are no unexpected values in the column.
        print("\n")  # Print a newline for better readability between columns.
# Out:
# No unexpected values in column 'facility_name'.
#
#
# No unexpected values in column 'score'.
#
#
# Unexpected values in column 'grade':
#              facility_name score grade  service_code service_description  \
# 34297  THREE BEARS BAR-B-Q    65                   1  ROUTINE INSPECTION
#
#       employee_id                         pe_description  program_element_pe  \
# 34297   EE0000958  RESTAURANT (0-30) SEATS MODERATE RISK                1631
#
#               program_name program_status  ZIP CODE
# 34297  THREE BEARS BAR-B-Q       INACTIVE     90061
#
#
# No unexpected values in column 'service_code'.
#
#
# No unexpected values in column 'service_description'.
#
#
# No unexpected values in column 'employee_id'.
#
#
# No unexpected values in column 'pe_description'.
#
#
# No unexpected values in column 'program_element_pe'.
#
#
# No unexpected values in column 'program_name'.
#
#
# No unexpected values in column 'program_status'.
#
#
# No unexpected values in column 'ZIP CODE'.

# %%
df_21 = df_21.drop(34297, axis=0) #drop the row no 34297 with invalid-value of grade

# %% [markdown]
# <a id="sec-1b-4-df_2"></a>
# ## Plotting graph to understand data
# [NavBar](#NavBar)

# %%
#source--->[2] for complete cell majorly chatGpt was used. prompt: give a frequncy plot for categorical variable. after this few modification were made.

# Set style for seaborn
sns.set(style="whitegrid")  # Set the style of seaborn plots to 'whitegrid' for better readability.

# Plot for `score`
plt.figure(figsize=(12, 6))  # Set the figure size to 12x6 for the score distribution plot.
sns.histplot(df_21['score'].astype(float), kde=True)  # Create a histogram of the 'score' column with a kernel density estimate.
plt.title('Score Distribution')  # Set the title of the histogram.
plt.xlabel('Score')  # Label the x-axis as 'Score'.
plt.ylabel('Frequency')  # Label the y-axis as 'Frequency'.
plt.show()  # Display the histogram.

plt.figure(figsize=(12, 6))  # Set the figure size to 12x6 for the score box plot.
sns.boxplot(x=df_21['score'].astype(float))  # Create a box plot of the 'score' column.
plt.title('Score Box Plot')  # Set the title of the box plot.
plt.xlabel('Score')  # Label the x-axis as 'Score'.
plt.show()  # Display the box plot.

# Plot for `grade`
plt.figure(figsize=(8, 5))  # Set the figure size to 8x5 for the grade distribution plot.
df_21['grade'].value_counts().plot(kind='bar', title='Grade Distribution')  # Create a bar plot of the 'grade' column with a title.
plt.xlabel('Grade')  # Label the x-axis as 'Grade'.
plt.ylabel('Count')  # Label the y-axis as 'Count'.
plt.show()  # Display the bar plot.

# Plot for `service_code`
plt.figure(figsize=(8, 5))  # Set the figure size to 8x5 for the service code frequency plot.
df_21['service_code'].value_counts().plot(kind='bar', title='Service Code Frequency')  # Create a bar plot of the 'service_code' column with a title.
plt.xlabel('Service Code')  # Label the x-axis as 'Service Code'.
plt.ylabel('Count')  # Label the y-axis as 'Count'.
plt.show()  # Display the bar plot.

# Plot for `service_description`
plt.figure(figsize=(8, 5))  # Set the figure size to 8x5 for the service description frequency plot.
df_21['service_description'].value_counts().plot(kind='bar', title='Service Description Frequency')  # Create a bar plot of the 'service_description' column with a title.
plt.xlabel('Service Description')  # Label the x-axis as 'Service Description'.
plt.ylabel('Count')  # Label the y-axis as 'Count'.
plt.show()  # Display the bar plot.

# Plot for `employee_id`
plt.figure(figsize=(12, 6))  # Set the figure size to 12x6 for the top 20 employee ID frequency plot.
df_21['employee_id'].value_counts().head(20).plot(kind='bar', title='Top 20 Employee ID Frequency')  # Create a bar plot of the top 20 most frequent 'employee_id' values with a title.
plt.xlabel('Employee ID')  # Label the x-axis as 'Employee ID'.
plt.ylabel('Count')  # Label the y-axis as 'Count'.
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability.
plt.show()  # Display the bar plot.

# Plot for `pe_description`
plt.figure(figsize=(12, 6))  # Set the figure size to 12x6 for the PE description frequency plot.
df_21['pe_description'].value_counts().plot(kind='bar', title='PE Description Frequency')  # Create a bar plot of the 'pe_description' column with a title.
plt.xlabel('PE Description')  # Label the x-axis as 'PE Description'.
plt.ylabel('Count')  # Label the y-axis as 'Count'.
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability.
plt.show()  # Display the bar plot.

# Plot for `program_element_pe`
plt.figure(figsize=(12, 6))  # Set the figure size to 12x6 for the program element frequency plot.
df_21['program_element_pe'].value_counts().plot(kind='bar', title='Program Element Frequency')  # Create a bar plot of the 'program_element_pe' column with a title.
plt.xlabel('Program Element')  # Label the x-axis as 'Program Element'.
plt.ylabel('Count')  # Label the y-axis as 'Count'.
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability.
plt.show()  # Display the bar plot.

# Plot for `program_name` (top 20 for clarity)
plt.figure(figsize=(12, 6))  # Set the figure size to 12x6 for the top 20 program name frequency plot.
df_21['program_name'].value_counts().head(20).plot(kind='bar', title='Top 20 Program Name Frequency')  # Create a bar plot of the top 20 most frequent 'program_name' values with a title.
plt.xlabel('Program Name')  # Label the x-axis as 'Program Name'.
plt.ylabel('Count')  # Label the y-axis as 'Count'.
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability.
plt.show()  # Display the bar plot.

# Plot for `program_status`
plt.figure(figsize=(8, 5))  # Set the figure size to 8x5 for the program status distribution plot.
df_21['program_status'].value_counts().plot(kind='bar', title='Program Status Distribution')  # Create a bar plot of the 'program_status' column with a title.
plt.xlabel('Program Status')  # Label the x-axis as 'Program Status'.
plt.ylabel('Count')  # Label the y-axis as 'Count'.
plt.show()  # Display the bar plot.

# Plot for `ZIP CODE`
plt.figure(figsize=(12, 6))  # Set the figure size to 12x6 for the ZIP code frequency plot.
df_21['ZIP CODE'].value_counts().plot(kind='bar', title='ZIP Code Frequency')  # Create a bar plot of the 'ZIP CODE' column with a title.
plt.xlabel('ZIP Code')  # Label the x-axis as 'ZIP Code'.
plt.ylabel('Count')  # Label the y-axis as 'Count'.
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability.
plt.show()  # Display the bar plot.

# %%
# Convert 'grade' to a categorical type
df_21['grade'] = df_21['grade'].astype('category')

# Plot using seaborn's scatterplot with categorical handling
plt.figure(figsize=(10, 6))
sns.scatterplot(x='score', y='grade', data=df_21, hue='grade', palette='viridis')
plt.title('Scatter Plot of Score vs Grade (Categorical Grade)')
plt.xlabel('Score')
plt.ylabel('Grade')
plt.grid(True)
plt.show()

# %% [markdown]
# <a id="section1(c)"></a>
# # (C): sammarization using SQL
# [NavBar](#NavBar)

# %%
df_11['SUPPORTIVE HOUSING'] = df_11['SUPPORTIVE HOUSING'].astype(object)  # Convert the 'SUPPORTIVE HOUSING' column to object data type.
df_11['SUPPORTIVE HOUSING'] = df_11['SUPPORTIVE HOUSING'].replace({'No': 0, 'Yes': 1})  # Replace 'No' with 0 and 'Yes' with 1 in the 'SUPPORTIVE HOUSING' column.
df_11['DEVELOPMENT STAGE'] = df_11['DEVELOPMENT STAGE'].replace({'no': 0, 'yes': 1})  # Replace 'no' with 0 and 'yes' with 1 in the 'DEVELOPMENT STAGE' column.

# %%
df_11['DEVELOPMENT STAGE']
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 5      0
#       ..
# 590    0
# 591    0
# 592    0
# 593    0
# 594    0
# Name: DEVELOPMENT STAGE, Length: 560, dtype: int64

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect('data_summary.db')
df_11.to_sql('df_11_table', conn, if_exists='replace', index=False)
# Out:
# 560

# %%
query = """
SELECT
    [ZIP CODE],
    COUNT(*) AS total_count,                               -- Count of rows per ZIP code
    AVG([DEVELOPMENT STAGE]) AS development_stages,  -- Count of unique development stages
    COUNT(DISTINCT [CONSTRUCTION TYPE]) AS unique_construction_types,  -- Count of unique construction types
    COUNT(DISTINCT [SITE  COUNCIL DISTRICT]) AS unique_site_council_districts, -- Count of unique site council districts
    SUM([SITE UNITS]) AS total_site_units,                 -- Sum of site units
    SUM([PROJECT TOTAL UNITS]) AS total_project_units,     -- Sum of project total units
    COUNT(DISTINCT [HOUSING TYPE]) AS unique_housing_types,  -- Count of unique housing types
    AVG([SUPPORTIVE HOUSING]) AS avg_supportive_housing,   -- Average supportive housing (if binary, shows proportion)
    AVG([SH UNITS PER SITE]) AS avg_sh_units_per_site,    -- Average SH units per site
    SUM([LAHD FUNDED]) AS total_lahd_funded,              -- Sum of LAHD funded (if binary, shows total count)
    AVG([LEVERAGE]) AS avg_leverage,                      -- Average leverage
    COUNT(DISTINCT [TAX EXEMPT CONDUIT BOND]) AS unique_tax_exempt_bonds,  -- Count of unique tax exempt conduit bonds
    SUM([TDC]) AS total_tdc,                              -- Sum of TDC
    MIN([IN-SERVICE DATE]) AS earliest_in_service_date,    -- Earliest in-service date
    MAX([IN-SERVICE DATE]) AS latest_in_service_date      -- Latest in-service date
FROM
    df_11_table
GROUP BY
    [ZIP CODE];
"""

# Execute the query and fetch the result into a DataFrame
summary_df_11 = pd.read_sql_query(query, conn)

# Close the SQLite connection
conn.close()

# %%
summary_df_11.head()
# Out:
#    ZIP CODE  total_count  development_stages  unique_construction_types  \
# 0     90002           19            0.315789                          2
# 1     90003           19            0.052632                          3
# 2     90004           13            0.230769                          3
# 3     90005            4            0.250000                          3
# 4     90006           23            0.043478                          4
#
#    unique_site_council_districts  total_site_units  total_project_units  \
# 0                              3               738                 2345
# 1                              2               691                 2351
# 2                              2               679                 1124
# 3                              2               433                  690
# 4                              2              1035                 2007
#
#    unique_housing_types  avg_supportive_housing  avg_sh_units_per_site  \
# 0                     2                0.368421               6.210526
# 1                     3                0.421053               7.052632
# 2                     3                0.769231              36.307692
# 3                     3                0.500000              36.750000
# 4                     4                0.391304              12.956522
#
#    total_lahd_funded  avg_leverage  unique_tax_exempt_bonds    total_tdc  \
# 0           51493751  1.645625e+07                        5  485955851.0
# 1           83196777  1.956192e+07                        7  510920216.0
# 2           66595284  2.057430e+07                        4  346710270.0
# 3            7501000  2.854807e+07                        3  142759221.0
# 4           71218513  1.609649e+07                        4  471901531.0
#
#   earliest_in_service_date latest_in_service_date
# 0      2006-01-01 00:00:00    2023-01-01 00:00:00
# 1      2006-01-01 00:00:00    2024-01-01 00:00:00
# 2      2006-01-01 00:00:00    2020-01-01 00:00:00
# 3      2006-01-01 00:00:00    2017-01-01 00:00:00
# 4      2006-01-01 00:00:00    2023-01-01 00:00:00

# %%
import sqlite3
import pandas as pd

# Sample DataFrame df_11
# df_11 = pd.read_csv('your_file.csv') # Example if loading from CSV

# Connect to SQLite database (or create it)
conn = sqlite3.connect('data_summary.db')

# Load DataFrame into SQLite database
df_21.to_sql('df_11_table', conn, if_exists='replace', index=False)
# Out:
# 67540

# %%
# Define the SQL query for summarization
query = """
SELECT 
    [ZIP CODE],
    COUNT(*) AS total_count,                      -- Count of rows per ZIP code
    AVG(score) AS average_score,                  -- Average score
    MAX(score) AS max_score,                      -- Maximum score
    MIN(score) AS min_score,                      -- Minimum score
    MAX(grade) AS max_grade,                      -- Maximum grade (adjust if grades are categorical)
    COUNT(DISTINCT service_code) AS unique_service_codes, -- Count of unique service codes
    MAX(service_description) AS latest_service_description, -- Latest service description
    COUNT(DISTINCT employee_id) AS unique_employees, -- Count of unique employee IDs
    MAX(pe_description) AS latest_pe_description,  -- Latest PE description
    MAX(program_element_pe) AS latest_program_element_pe, -- Latest program element PE
    MAX(program_name) AS latest_program_name,     -- Latest program name
    COUNT(DISTINCT program_status) AS unique_program_statuses, -- Count of unique program statuses
    COUNT(DISTINCT [ZIP CODE]) AS zip_code_count -- Count of distinct ZIP codes (should be 1 per group)
FROM 
    df_11_table
GROUP BY 
    [ZIP CODE];
"""

# Execute the query and fetch the result into a DataFrame
summary_df_21 = pd.read_sql_query(query, conn)

# Close the SQLite connection
conn.close()

# %%
summary_df_21.head()
# Out:
#    ZIP CODE  total_count  average_score  max_score  min_score max_grade  \
# 0     90001         1173      93.846547        100         71         C
# 1     90002          265      94.649057        100         72         C
# 2     90003         1184      92.693412        100         70         C
# 3     90004         1422      92.867089        100         72         C
# 4     90005         1655      91.441088        100         65         C
#
#    unique_service_codes latest_service_description  unique_employees  \
# 0                     2         ROUTINE INSPECTION                12
# 1                     2         ROUTINE INSPECTION                 8
# 2                     2         ROUTINE INSPECTION                12
# 3                     2         ROUTINE INSPECTION                14
# 4                     2         ROUTINE INSPECTION                11
#
#                      latest_pe_description  latest_program_element_pe  \
# 0  RESTAURANT (61-150) SEATS MODERATE RISK                       1641
# 1  RESTAURANT (61-150) SEATS MODERATE RISK                       1641
# 2  RESTAURANT (61-150) SEATS MODERATE RISK                       1638
# 3  RESTAURANT (61-150) SEATS MODERATE RISK                       1641
# 4  RESTAURANT (61-150) SEATS MODERATE RISK                       1641
#
#             latest_program_name  unique_program_statuses  zip_code_count
# 0        ZARAGOZA'S MINI MARKET                        2               1
# 1  WATTS SENIOR CITIZENS CENTER                        2               1
# 2                 ZACATECAS BAR                        2               1
# 3                       Z PIZZA                        2               1
# 4            ZWONNY KITCHEN INC                        2               1

# %% [markdown]
# <a id="section1(d)"></a>
# ## (D) joining both data frame into one by ZIP Code
# [NavBar](#NavBar)

# %%
import sqlite3

# Connect to SQLite database
conn = sqlite3.connect('data_summary.db')

# Load df_11 into SQLite table
summary_df_11.to_sql('df_11_table', conn, if_exists='replace', index=False)

# Load df_21 into SQLite table
summary_df_21.to_sql('df_21_table', conn, if_exists='replace', index=False)
# Out:
# 99

# %%
# SQL query to join tables by ZIP code and select predictor and potential predicted variables
query = """
SELECT
    df_11_table."ZIP CODE",
    df_11_table."total_count",
    df_11_table."avg_sh_units_per_site",
    df_11_table."total_site_units",
    df_11_table."avg_supportive_housing",
    df_11_table."development_stages",
    df_21_table."average_score"
FROM
    df_11_table
INNER JOIN
    df_21_table
ON
    df_11_table."ZIP CODE" = df_21_table."ZIP CODE";
"""
# Execute the query and fetch the result into a DataFrame
joined_df = pd.read_sql_query(query, conn)

# Close the SQLite connection
conn.close()

# Display the result
print(joined_df)
# Out:
#     ZIP CODE  total_count  avg_sh_units_per_site  total_site_units  \
# 0      90002           19               6.210526               738
# 1      90003           19               7.052632               691
# 2      90004           13              36.307692               679
# 3      90005            4              36.750000               433
# 4      90006           23              12.956522              1035
# 5      90007           18               2.000000               420
# 6      90008            2              25.500000               172
# 7      90011           28               4.107143              1007
# 8      90012            9               7.666667              1572
# 9      90013           13             102.615385              1464
# 10     90014           10              67.400000               787
# 11     90015            8              26.375000               376
# 12     90016            9               6.222222               227
# 13     90017           19              18.947368              1240
# 14     90018           15               9.333333               476
# 15     90019           11              12.909091               289
# 16     90020            5               8.600000               255
# 17     90021            4              52.500000               230
# 18     90023            5              24.000000               277
# 19     90025            2              47.000000               125
# 20     90026           23              20.782609              1344
# 21     90027           11               1.363636               340
# 22     90028           11               9.727273               715
# 23     90029           12              18.000000               623
# 24     90031            9               5.444444               904
# 25     90032            2              31.500000               110
# 26     90033           10              17.900000               458
# 27     90035            1              12.000000                47
# 28     90037           28              11.607143              1173
# 29     90038           14               9.428571               443
# 30     90039            2               0.000000                34
# 31     90041            3              13.333333               143
# 32     90042            2               0.000000                65
# 33     90043            5              37.200000               330
# 34     90044           16              18.437500               760
# 35     90045            2              79.000000               222
# 36     90046            1              24.000000                24
# 37     90047            3              62.666667               204
# 38     90057           25              22.160000              1606
# 39     90059            5              12.600000               110
# 40     90061            6              27.000000               207
# 41     90062           11               5.636364               217
# 42     90063            1              32.000000                49
# 43     90064            2              17.000000               107
# 44     90065            6              14.166667               321
# 45     90066            2              11.000000                73
# 46     90068            2              30.500000                83
# 47     90230            1              30.000000               124
# 48     90291            3              29.333333                95
# 49     90292            2              34.500000               119
# 50     91324            2              57.500000               194
# 51     91401            1               0.000000                40
# 52     91601            3              20.666667               171
#
#     avg_supportive_housing  development_stages  average_score
# 0                 0.368421            0.315789      94.649057
# 1                 0.421053            0.052632      92.693412
# 2                 0.769231            0.230769      92.867089
# 3                 0.500000            0.250000      91.441088
# 4                 0.391304            0.043478      92.740653
# 5                 0.111111            0.000000      94.804917
# 6                 0.500000            0.000000      94.155280
# 7                 0.321429            0.035714      93.328180
# 8                 0.222222            0.222222      93.414478
# 9                 1.000000            0.153846      94.506422
# 10                1.000000            0.000000      94.217391
# 11                0.375000            0.000000      94.131627
# 12                0.333333            0.000000      93.470874
# 13                0.526316            0.052632      93.844706
# 14                0.400000            0.066667      94.006757
# 15                0.272727            0.000000      92.648227
# 16                0.400000            0.000000      91.225040
# 17                1.000000            0.000000      94.074783
# 18                0.600000            0.000000      93.546748
# 19                1.000000            0.000000      93.396278
# 20                0.521739            0.217391      93.327609
# 21                0.454545            0.000000      93.784568
# 22                0.363636            0.090909      93.753208
# 23                0.333333            0.083333      93.022254
# 24                0.111111            0.111111      93.576208
# 25                0.500000            0.000000      92.821181
# 26                0.400000            0.100000      93.203085
# 27                1.000000            0.000000      92.429363
# 28                0.321429            0.035714      94.289513
# 29                0.357143            0.000000      93.841791
# 30                0.000000            0.000000      93.405815
# 31                0.333333            0.000000      94.069038
# 32                0.000000            0.000000      93.322949
# 33                0.600000            0.000000      93.228000
# 34                0.312500            0.187500      92.938462
# 35                1.000000            1.000000      94.118336
# 36                1.000000            0.000000      92.627468
# 37                1.000000            1.000000      94.003035
# 38                0.480000            0.040000      92.511765
# 39                0.200000            0.000000      94.810888
# 40                0.500000            0.000000      93.717087
# 41                0.363636            0.272727      94.322581
# 42                1.000000            1.000000      93.112617
# 43                0.500000            0.000000      93.405496
# 44                0.333333            0.000000      93.106439
# 45                0.500000            0.000000      93.556186
# 46                1.000000            0.500000      93.628125
# 47                1.000000            0.000000      93.950000
# 48                1.000000            0.000000      92.407407
# 49                1.000000            0.500000      92.666667
# 50                0.500000            0.500000      94.000000
# 51                0.000000            0.000000      95.500000
# 52                0.666667            0.000000      95.000000

# %%
joined_df.head()
# Out:
#    ZIP CODE  total_count  avg_sh_units_per_site  total_site_units  \
# 0     90002           19               6.210526               738
# 1     90003           19               7.052632               691
# 2     90004           13              36.307692               679
# 3     90005            4              36.750000               433
# 4     90006           23              12.956522              1035
#
#    avg_supportive_housing  development_stages  average_score
# 0                0.368421            0.315789      94.649057
# 1                0.421053            0.052632      92.693412
# 2                0.769231            0.230769      92.867089
# 3                0.500000            0.250000      91.441088
# 4                0.391304            0.043478      92.740653

# %%
joined_df.shape
# Out:
# (53, 7)

# %% [markdown]
# <a id='section1(e)'></a>
# # (E) Formulating and testing Hypothesis
# ### source {1}: Introduction to statistical learning with python(majorly this book was followed in code and theoretical aspects of hypothesis testing.)
# [NavBar](#NavBar)

# %% [markdown]
# <p style="font-size:20px;"> <u>Null Hypothesis (H₀)</u>: The coefficient of the independent variable is zero (i.e., the variable has no effect on the dependent variable).<br>
#     <u>Alternative Hypothesis (H₁)</u>: The coefficient of the independent variable is not zero (i.e., the variable has an effect on the dependent variable) <br>
#     <u>Significance level</u>: p-value < 0.05 --> Alternate Hypothesis is true

# %%
joined_df.columns
# Out:
# Index(['ZIP CODE', 'total_count', 'avg_sh_units_per_site', 'total_site_units',
#        'avg_supportive_housing', 'development_stages', 'average_score'],
#       dtype='object')

# %%
joined_df.columns
# Out:
# Index(['ZIP CODE', 'total_count', 'avg_sh_units_per_site', 'total_site_units',
#        'avg_supportive_housing', 'development_stages', 'average_score'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

# Assuming joined_df is your DataFrame
predictors = ['avg_sh_units_per_site', 'total_site_units', 
              'avg_supportive_housing', 'development_stages']

X = joined_df[predictors]  # Independent variables
y = joined_df['average_score']  # Dependent variable

# Add constant to the model (intercept)
X = sm.add_constant(X)

# Fit the model
model_1 = sm.OLS(y, X).fit()

# Predicted values
y_pred = model_1.predict(X)

# Residuals
residuals = y - y_pred

# %%
import statsmodels.api as sm

X = joined_df[predictors]  # Independent variables
y = joined_df['average_score']  # Dependent variable

# Add constant to the model (intercept)
X = sm.add_constant(X)

# Fit the model
model_1 = sm.OLS(y, X).fit()

# Summary of the regression
print(model_1.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          average_score   R-squared:                       0.096
# Model:                            OLS   Adj. R-squared:                  0.020
# Method:                 Least Squares   F-statistic:                     1.268
# Date:                Sun, 08 Sep 2024   Prob (F-statistic):              0.296
# Time:                        20:58:07   Log-Likelihood:                -61.710
# No. Observations:                  53   AIC:                             133.4
# Df Residuals:                      48   BIC:                             143.3
# Df Model:                           4
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                     93.8843      0.279    336.850      0.000      93.324      94.445
# avg_sh_units_per_site      0.0158      0.008      1.895      0.064      -0.001       0.033
# total_site_units          -0.0002      0.000     -0.800      0.428      -0.001       0.000
# avg_supportive_housing    -1.2039      0.556     -2.163      0.036      -2.323      -0.085
# development_stages         0.0681      0.509      0.134      0.894      -0.955       1.091
# ==============================================================================
# Omnibus:                        6.380   Durbin-Watson:                   1.537
# Prob(Omnibus):                  0.041   Jarque-Bera (JB):                5.949
# Skew:                          -0.533   Prob(JB):                       0.0511
# Kurtosis:                       4.247   Cond. No.                     3.34e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.34e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# Residual plot
plt.figure(figsize=(8, 6))  # Set the figure size to 8x6 for the residual plot.
plt.scatter(y_pred, residuals, color='green', alpha=0.6)  # Create a scatter plot of predicted values vs residuals with green points and transparency set to 0.6.
plt.axhline(y=0, color='red', linestyle='--')  # Add a horizontal line at y=0 in red with a dashed linestyle to represent the zero residual line.

plt.title('Residual Plot for Multiple Linear Regression')  # Set the title of the plot.
plt.xlabel('Predicted Values of average_score')  # Label the x-axis as 'Predicted Values of average_score'.
plt.ylabel('Residuals')  # Label the y-axis as 'Residuals'.

plt.show()  # Display the residual plot.

# %%
import statsmodels.api as sm

# Assuming df is your DataFrame and 'ZIP CODE' is excluded from predictors
predictors = ['avg_supportive_housing']

X = joined_df[predictors]  # Independent variables
y = joined_df['average_score']  # Dependent variable

# Add constant to the model (intercept)
X = sm.add_constant(X)

# Fit the model
model_2 = sm.OLS(y, X).fit()

# Summary of the regression
print(model_2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          average_score   R-squared:                       0.018
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                    0.9105
# Date:                Sun, 08 Sep 2024   Prob (F-statistic):              0.344
# Time:                        21:02:50   Log-Likelihood:                -63.903
# No. Observations:                  53   AIC:                             131.8
# Df Residuals:                      51   BIC:                             135.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                     93.7090      0.227    412.652      0.000      93.253      94.165
# avg_supportive_housing    -0.3536      0.371     -0.954      0.344      -1.097       0.390
# ==============================================================================
# Omnibus:                        2.778   Durbin-Watson:                   1.670
# Prob(Omnibus):                  0.249   Jarque-Bera (JB):                1.826
# Skew:                          -0.368   Prob(JB):                        0.401
# Kurtosis:                       3.534   Cond. No.                         4.27
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Scatter plot with regression line
# Predicted values
y_pred = model_2.predict(X)

# Residuals
residuals = y - y_pred

plt.figure(figsize=(8, 6))  # Set the figure size to 8x6 for the regression plot.
plt.scatter(joined_df['avg_supportive_housing'], joined_df['average_score'], color='blue', alpha=0.6, label='Data')  # Create a scatter plot of 'avg_supportive_housing' vs 'average_score' with blue points and transparency set to 0.6, and label it as 'Data'.
plt.plot(joined_df['avg_supportive_housing'], y_pred, color='red', label='Fitted Line')  # Plot the fitted regression line in red with a label 'Fitted Line'.

plt.title('Regression: avg_supportive_housing vs average_score')  # Set the title of the plot.
plt.xlabel('avg_supportive_housing')  # Label the x-axis as 'avg_supportive_housing'.
plt.ylabel('average_score')  # Label the y-axis as 'average_score'.
plt.legend()  # Display the legend to differentiate between 'Data' and 'Fitted Line'.

plt.show()  # Display the regression plot.

# %%
import statsmodels.api as sm

# Assuming df is your DataFrame and 'ZIP CODE' is excluded from predictors
predictors = ['avg_sh_units_per_site']

X = joined_df[predictors]  # Independent variables
y = joined_df['average_score']  # Dependent variable

# Add constant to the model (intercept)
X = sm.add_constant(X)

# Fit the model
model_3 = sm.OLS(y, X).fit()

# Summary of the regression
print(model_3.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          average_score   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                 -0.013
# Method:                 Least Squares   F-statistic:                    0.3393
# Date:                Sun, 08 Sep 2024   Prob (F-statistic):              0.563
# Time:                        21:05:40   Log-Likelihood:                -64.196
# No. Observations:                  53   AIC:                             132.4
# Df Residuals:                      51   BIC:                             136.3
# Df Model:                           1
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                    93.4472      0.170    548.262      0.000      93.105      93.789
# avg_sh_units_per_site     0.0032      0.005      0.583      0.563      -0.008       0.014
# ==============================================================================
# Omnibus:                        2.641   Durbin-Watson:                   1.601
# Prob(Omnibus):                  0.267   Jarque-Bera (JB):                1.758
# Skew:                          -0.259   Prob(JB):                        0.415
# Kurtosis:                       3.727   Cond. No.                         46.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Scatter plot with regression line
# Predicted values
y_pred = model_3.predict(X)
residuals = y - y_pred  # Calculate residuals as the difference between actual values (y) and predicted values (y_pred).

plt.figure(figsize=(8, 6))  # Set the figure size to 8x6 for the regression plot.
plt.scatter(joined_df['avg_sh_units_per_site'], joined_df['average_score'], color='blue', alpha=0.6, label='Data')  # Create a scatter plot of 'avg_sh_units_per_site' vs 'average_score' with blue points and transparency set to 0.6, and label it as 'Data'.
plt.plot(joined_df['avg_sh_units_per_site'], y_pred, color='red', label='Fitted Line')  # Plot the fitted regression line in red with a label 'Fitted Line'.

plt.title('Regression: avg_sh_units_per_site vs average_score')  # Set the title of the plot.
plt.xlabel('avg_sh_units_per_site')  # Label the x-axis as 'avg_sh_units_per_site'.
plt.ylabel('average_score')  # Label the y-axis as 'average_score'.
plt.legend()  # Display the legend to differentiate between 'Data' and 'Fitted Line'.

plt.show()  # Display the regression plot.

# %%
import statsmodels.api as sm

# Assuming df is your DataFrame and 'ZIP CODE' is excluded from predictors
predictors = ['avg_sh_units_per_site','avg_supportive_housing']

X = joined_df[predictors]  # Independent variables
y = joined_df['average_score']  # Dependent variable

# Add constant to the model (intercept)
X = sm.add_constant(X)

# Fit the model
model_4 = sm.OLS(y, X).fit()

# Summary of the regression
print(model_4.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          average_score   R-squared:                       0.083
# Model:                            OLS   Adj. R-squared:                  0.046
# Method:                 Least Squares   F-statistic:                     2.258
# Date:                Sun, 08 Sep 2024   Prob (F-statistic):              0.115
# Time:                        21:08:33   Log-Likelihood:                -62.080
# No. Observations:                  53   AIC:                             130.2
# Df Residuals:                      50   BIC:                             136.1
# Df Model:                           2
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                     93.7513      0.223    420.928      0.000      93.304      94.199
# avg_sh_units_per_site      0.0145      0.008      1.887      0.065      -0.001       0.030
# avg_supportive_housing    -1.0649      0.522     -2.039      0.047      -2.114      -0.016
# ==============================================================================
# Omnibus:                        5.291   Durbin-Watson:                   1.561
# Prob(Omnibus):                  0.071   Jarque-Bera (JB):                4.690
# Skew:                          -0.450   Prob(JB):                       0.0959
# Kurtosis:                       4.146   Cond. No.                         154.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Predicted values
y_pred = model_4.predict(X)

# Residuals
residuals = y - y_pred

# Residual plot
plt.figure(figsize=(8, 6))  # Set the figure size to 8x6 for the residual plot.
plt.scatter(y_pred, residuals, color='green', alpha=0.6)  # Create a scatter plot of predicted values vs residuals with green points and transparency set to 0.6.
plt.axhline(y=0, color='red', linestyle='--')  # Add a horizontal line at y=0 in red with a dashed linestyle to represent the zero residual line.

plt.title('Residual Plot for Multiple Linear Regression')  # Set the title of the plot.
plt.xlabel('Predicted Values of average_score')  # Label the x-axis as 'Predicted Values of average_score'.
plt.ylabel('Residuals')  # Label the y-axis as 'Residuals'.

plt.show()  # Display the residual plot.

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor  # Import the variance inflation factor function to check for multicollinearity.

predictors = ['avg_sh_units_per_site', 'total_site_units',  # Define the list of predictor variables for the regression model.
              'avg_supportive_housing', 'development_stages']
X = sm.add_constant(joined_df[predictors])  # Add a constant term to the predictors DataFrame to account for the intercept in the regression model.
vif = pd.DataFrame()  # Initialize an empty DataFrame to store the VIF values.
vif["Variable"] = X.columns  # Add a column to the DataFrame for variable names.
vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]  # Calculate the VIF for each predictor and add it to the DataFrame.
print(vif)  # Print the DataFrame with variables and their corresponding VIF values.
# Out:
#                  Variable       VIF
# 0                   const  6.204321
# 1   avg_sh_units_per_site  2.397163
# 2        total_site_units  1.101383
# 3  avg_supportive_housing  2.305993
# 4      development_stages  1.289766

# %% [markdown]
# <p style="font-size:18px;"><b>const (Intercept)</b>: VIF of 6.204321</p>
# While typically VIF values for intercept terms are not critical, this value suggests some level of multicollinearity involving the intercept, but it's not the main concern for assessing multicollinearity among predictors.<br>
# <p style="font-size:18px;"><b>avg_sh_units_per_site</b>: VIF of 2.397163:</p> This is within an acceptable range. Multicollinearity is not a serious concern for this predictor.<br>
#
# <p style="font-size:18px;"><b>total_site_units</b>: VIF of 1.101383:</p> This indicates very low multicollinearity. This predictor does not contribute significantly to multicollinearity.<br>
#
# <p style="font-size:18px;"><b>avg_supportive_housing</b>: VIF of 2.30599:</p> This is also within an acceptable range. Multicollinearity is not severe for this predictor.<Br>
#
# <p style="font-size:18px;"><b>development_stages</b>: VIF of 1.289766:</p> This indicates very low multicollinearity. This predictor does not contribute significantly to multicollinearity.

# %% [markdown]
# <a id="Result"></a>
# # Regression Analysis Results
# [NavBar](#NavBar)
# ## Simple Linear Regression Results
#
# ### 1. `avg_sh_units_per_site`
# - **R-squared**: 0.007
# - **Adjusted R-squared**: -0.013
# - **F-statistic**: 0.3393
# - **p-value (F-statistic)**: 0.563
# - **Coefficient**: 0.0032
# - **Standard Error**: 0.005
# - **t-value**: 0.583
# - **p-value (Coefficient)**: 0.563
#
# ### 2. `avg_supportive_housing`
# - **R-squared**: 0.018
# - **Adjusted R-squared**: -0.002
# - **F-statistic**: 0.9105
# - **p-value (F-statistic)**: 0.344
# - **Coefficient**: -0.3536
# - **Standard Error**: 0.371
# - **t-value**: -0.954
# - **p-value (Coefficient)**: 0.344
#
# ## Multiple Linear Regression Results
#
# - **R-squared**: 0.083
# - **Adjusted R-squared**: 0.046
# - **F-statistic**: 2.258
# - **p-value (F-statistic)**: 0.115
#
# ### Coefficients
# - **avg_sh_units_per_site**:
#   - **Coefficient**: 0.0145
#   - **Standard Error**: 0.008
#   - **t-value**: 1.887
#   - **p-value**: 0.065
# - **avg_supportive_housing**:
#   - **Coefficient**: -1.0649
#   - **Standard Error**: 0.522
#   - **t-value**: -2.039
#   - **p-value**: 0.047
#
# ## Conclusion
#
# - **Simple Linear Regression**: Both `avg_sh_units_per_site` and `avg_supportive_housing` have very low R-squared values and high p-values, indicating that neither predictor is statistically significant on its own.
#
# - **Multiple Linear Regression**: `avg_supportive_housing` is significant in the multiple regression model, suggesting it may have a meaningful effect when other predictors are considered. However, the overall model is not significant, indicating that additional predictors might be necessary.
#
# - **Result**: <u><b>Considering the above observations we can not reject the null Hypothesis.</b></u>

# %% [markdown]
# <a id="Q2"></a>
# # Q2:EDA on WPI-2004-05-March2017.csv
# [NavBar](#NavBar)

# %%
df_4 = pd.read_csv('WPI-2004-05-March2017.csv')

# %%
df_4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 797 entries, 0 to 796
# Columns: 158 entries, COMMODITIES to Mar-17
# dtypes: float64(157), object(1)
# memory usage: 983.9+ KB

# %%
df_4.isnull().sum()
# Out:
# COMMODITIES    0
# Weight         0
# Apr-04         5
# May-04         5
# Jun-04         5
#               ..
# Nov-16         2
# Dec-16         2
# Jan-17         2
# Feb-17         2
# Mar-17         2
# Length: 158, dtype: int64

# %%
df_4.shape
# Out:
# (797, 158)

# %%
df_4.shape
# Out:
# (797, 158)

# %%
# Get the current column names
current_columns = df_4.columns

# Define new column names for all columns except the first two
new_column_names = list(range(1, len(current_columns)-1))

# Combine the first two original column names with the new numerical names
all_new_column_names = list(current_columns[:2]) + new_column_names

# Set the new column names to the DataFrame
df_4.columns = all_new_column_names

# %%
df_4.columns
# Out:
# Index(['COMMODITIES',      'Weight',             1,             2,
#                    3,             4,             5,             6,
#                    7,             8,
#        ...
#                  147,           148,           149,           150,
#                  151,           152,           153,           154,
#                  155,           156],
#       dtype='object', length=158)

# %%
df_4['COMMODITIES'].unique()
# Out:
# array(['ALL COMMODITIES', 'I    PRIMARY ARTICLES', '(A)  FOOD ARTICLES',
#        'a.  FOOD GRAINS(CEREALS+PULSES)', 'a1. CEREALS', 'Rice', 'Wheat',
#        'Jowar', 'Bajra', 'Maize', 'Barley', 'Ragi', 'a2. PULSES', 'Gram',
#        'Arhar', 'Moong', 'Masur', 'Urad', 'b.  FRUITS & VEGETABLES',
#        'b1. VEGETABLES', 'Potato', 'Sweet Potato', 'Onion', 'Tapioca',
#        'Ginger(Fresh)', 'Peas(Green)', 'Tomato', 'Cauliflower', 'Brinjal',
#        'Okra (Lady finger)', 'Cabbage', 'b2. FRUITS', 'Banana', 'Mango',
#        'Apple', 'Orange', 'Cashew nut', 'Coconut(Fresh)', 'Papaya',
#        'Grapes', 'Pineapple', 'Guava', 'Litchi', 'Lemon', 'Sapota',
#        'c.  MILK', 'Milk', 'd.  EGGS,MEAT & FISH', 'Egg', 'Fish-Inland',
#        'Fish-Marine', 'Mutton', 'Beef & Buffalo Meat', 'Poultry Chicken',
#        'Pork', 'e.  CONDIMENTS & SPICES', 'Black Pepper', 'Chillies(Dry)',
#        'Turmeric', 'Cardamom', 'Ginger(Dry)', 'Betelnut/Arecanut',
#        'Cummin', 'Garlic', 'Corriander', 'f.  OTHER FOOD ARTICLES', 'Tea',
#        'Coffee', '(B)  NON-FOOD ARTICLES', 'a.  FIBRES', 'Raw Cotton',
#        'Raw Jute', 'Mesta', 'Raw Wool', 'Raw Silk', 'Coir Fibre',
#        'b.  OIL SEEDS', 'Groundnut Seed', 'Rape & Mustard Seed',
#        'Cotton Seed', 'Copra (Coconut)', 'Gingelly Seed (Sesamum)',
#        'Linseed', 'Castor Seed', 'Niger Seed', 'Safflower (Kardi Seed)',
#        'Sunflower', 'Soyabean', 'c.  OTHER NON-FOOD ARTICLES',
#        'Hides(Raw)', 'Skins(Raw)', 'Tanning Materials', 'Sugarcane',
#        'Tobacco', 'Gaur Seed', 'Raw Rubber', 'Logs & Timber', 'Fodder',
#        'd.   FLORICULTURE', 'Rose', 'Jasmine', 'Marigold',
#        '(C)  MINERALS', 'a.  METALLIC MINERALS', 'Bauxite', 'Chromite',
#        'Copper Ore', 'Zinc Concentrate', 'Manganese Ore', 'Iron Ore',
#        'b.  OTHER MINERALS', 'Phosphorite', 'Fireclay', 'Gypsum',
#        'Kaolin', 'Dolomite', 'Magnesite', 'Barytes', 'Limestone',
#        'Steatite', 'Graphite', 'Sillimanite', 'c.  CRUDE PETROLEUM',
#        'Crude Petroleum', 'II   FUEL & POWER', 'A.   COAL', 'Coking Coal',
#        'Non-Coking Coal', 'Coke', 'Lignite', 'B.   MINERAL OILS', 'LPG',
#        'Petrol', 'Kerosene', 'Aviation Turbine Fuel', 'High Speed Diesel',
#        'Naphtha', 'Light Diesel Oil', 'Bitumen', 'Furnace Oil',
#        'Lubricants', 'C.   ELECTRICITY', 'Electricity ( Domestic)',
#        'Electricity (Commercial)', 'Electricity (Agricultural)',
#        'Electricity (Railway Traction)', 'Electricity (Industry)',
#        'III  MANUFACTURED PRODUCTS', '(A)  FOOD PRODUCTS',
#        'a.  DAIRY PRODUCTS', 'Powder Milk', 'Ghee', 'Butter', 'Ice Cream',
#        'Condensed Milk', 'b.  CANNING, PRESERVING & PROCESSING OF FOOD',
#        'Canned Fish', 'Fish Meal', 'Processed Prawn', 'Canned Meat',
#        'Vegetables Seeds', 'c.  GRAIN MILL PRODUCTS', 'Maida',
#        'Wheat Flour ( Atta)', 'Gram Powder (Besan)', 'Sooji ( Rawa )',
#        'Rice Bran', 'Wheat Bran', 'Beaten Rice Flakes (Chire)',
#        'Maize Atta', 'Other Grain Mill Products', 'd.  BAKERY PRODUCTS',
#        'Biscuit / Cookies', 'Bread & Buns', 'Cakes & Muffins',
#        'e.  SUGAR, KHANDSARI & GUR', 'Sugar', 'Gur', 'Khandsari',
#        'Molasses', 'Bagasse', 'Sugar Confectionary', 'f.  EDIBLE OILS',
#        'Vanaspati', 'Groundnut Oil', 'Palm Oil', 'Rice Bran Oil',
#        'Cotton Seed Oil', 'Mustard & Rapeseed Oil', 'Soyabean Oil',
#        'Copra Oil', 'Sunflower Oil', 'Gingelly Oil', 'g.  OIL CAKES',
#        'Cotton Seed Oil Cake', 'Rice Bran Extraction', 'Mustard Oil Cake',
#        'Groundnut Oil Cake', 'Other Oil Cakes',
#        'h.  TEA & COFFEE PROCCESSING', 'Tea Leaf (Blended)',
#        'Tea Leaf (Unblended)', 'Tea Dust (Blended)',
#        'Tea Dust (Unblended)', 'Coffee Powder', 'i.  MANUFACTURE OF SALT',
#        'Salt', 'j.  OTHER FOOD PRODUCTS', 'Cashew Kernel',
#        'Gola (Cattle Feed)', 'Papad', 'Cashew nut (Roasted)',
#        'Mixed Spices', 'Pickles', 'Soya Preparations (Excluding Oil)',
#        'Readymade / Instant Food Powder',
#        '(B)  BEVERAGES, TOBACCO & TOBACCO PRODUCTS',
#        'a.  WINE INDUSTRIES', 'IMFL  - Blended',
#        'IMFL - Malted but not Blended', 'Rectified Spirit',
#        'b.  MALT LIQUOR', 'Beer', 'Toddy (or Taddy)',
#        'c.  SOFT DRINKS & CARBONATED WATER', 'Soda Based Soft Drinks',
#        'Soft Drink Concentrates', 'Aerated Water (All Types)',
#        'Non-Alcoholic Beverages (All Types)', 'Mineral  Water',
#        'd.  MANUFACTURE OF BIDI,CIGARETTES,TOBACCO & ZARDA', 'Cigarette',
#        'Bidi', 'Dried Tobacco', 'Chewing Tobacco (scented or not )',
#        'Zarda', '(C ) TEXTILES', 'a.  COTTON TEXTILES',
#        'a1.  COTTON YARN', 'Cotton Yarn (Unbleached)',
#        'Cotton Yarn  (Bleached)', 'Cotton Yarn (Dyed)',
#        'Fnished / processed cotton yarn (not knitted)',
#        'Finished / processed  cotton  yarn (knitted)',
#        'a2.  COTTON FABRIC', 'Cotton Cloth finished /processed',
#        'Grey Cloth (Bleached / Unbleached)',
#        'Cotton Textiles Dyed/printed', 'Bed Cover & Bed Sheet',
#        'Other  Cotton Hosiery Goods', 'Cotton Linters', 'Cotton Shirting',
#        'Cotton Trousers / Pants', 'Cotton Towel Cloth', 'Cotton Durries',
#        'Furnishing cloth', 'b.  MAN MADE TEXTILES', 'b1.  MAN MADE FIBRE',
#        'Polyester Yarn', 'Texturised and Twisted Yarn',
#        'Polyester Staple Fibre', 'Synthetic Yarn', 'Viscose Staple Fibre',
#        'Acrylic Fibre', 'Acrylic Yarn', 'Nylon Yarn', 'Viscose Yarn',
#        'Synthetic Fibres', 'b2.  MAN MADE FABRIC', 'Mixed  Fabrics',
#        'Cotton  Knitted Fabrics', 'Synthetic Suitings (incl.blended)',
#        'Synthetic Grey Cloth', 'Nylon Thread', 'Polyethlene Fabrics',
#        'Other Synthetic Fabrics', 'c.  WOOLLEN TEXTILES', 'Woollen Yarn',
#        'Woollen Carpets', 'Woollen  Shawls', 'Woollen Hosiery goods',
#        'Woollen Cloth', 'Woollen Cardigans/Sweaters', 'Blankets',
#        'Other Woollen Garments', 'd.  JUTE HEMP & MESTA TEXTILES',
#        'Jute Sacking Cloth', 'Jute Sacking Bag', 'Tyre Cord Fabric',
#        'Jute Yarn', 'Gunny and Hessian Cloth', 'e.  OTHER MISC. TEXTILES',
#        'Cotton Shirts', 'Terene Garments', 'Cotton Children suits',
#        'Terry Towel', 'Gunny bags (Non Laminated)', 'Coir Mats & Matting',
#        'Cotton Under Garments', 'Cotton Pillow Cover',
#        'Cotton Dressing Gown', '(D)  WOOD & WOOD PRODUCTS',
#        'a.  TIMBER / WOODEN PLANKS', 'Sawn/ResawnTimber/Wooden Planks',
#        'Sawn Timber Posts / Squares', 'b.  PROCESSED WOOD',
#        'Processed/ Sized Wood Cutting',
#        'Wooden Almirah / Cabinets/ Cupboard',
#        'Wooden Crates & Packing Box', 'Wooden Chair',
#        'c.  PLYWOOD & FIBRE BOARD', 'Plywood Board', 'Insulation Board',
#        'd.  OTHERS', 'Veneered Particle Board', 'Veneer Wood',
#        '(E)  PAPER & PAPER PRODUCTS', 'a.  PAPER & PULP',
#        'Printing and Writing Paper', 'Kraft  Paper & Bags', 'Newsprint',
#        'Laminated Paper', 'Paper for Printing / Poster', 'Maplitho Paper',
#        'Computer Stationery', 'Paper Rolls', 'Paper Cone & Tube',
#        'Cream  Laid woven Paper', 'Paper Pulp',
#        'b.  MANUFACTURE OF BOARDS', 'Corrugated Sheet Boxes',
#        'Paper Cartons / boxes', 'Bristle Paper Board', 'Card Board',
#        'c.  PRINTING & PUBLISHING', 'Books/ Periodicals/ Journals',
#        'Newspaper', 'Other Printing and Publishing',
#        '(F)  LEATHER & LEATHER PRODUCTS', 'a.  LEATHERS',
#        'Vegetable  Tanned  Leather', 'Crome Tanned Leather',
#        'Leather Shoe lining', 'b.  LEATHER FOOTWEAR',
#        'Leather Shoe Upper', 'Foot Wear/ Safety Boot',
#        'Leather Chappals/ sandals', 'Leather Sole',
#        'Other Leather Foot Wear', 'c.  OTHER LEATHER PRODUCTS',
#        'Leather Garments & Jackets', 'Leather Bags',
#        'Leather Handbags / Wallets', 'Leather  Gloves',
#        'Leather Harness Goods', '(G)  RUBBER & PLASTIC PRODUCTS',
#        'a.  TYRES & TUBES', 'a1.  TYRES', 'Cab/Car Tyre',
#        'Bus/truck Tyre', 'Scooter / Motor cycle Tyre', 'Tractor Tyre',
#        'Cycle /Cycle rickshaw Tyre', 'a2.  TUBES',
#        'Cycle / Rickshaw Tube', 'Motor Tube', 'Other Rubber Tubes',
#        'b.  PLASTIC PRODUCTS', 'Plastic/PVC Pipe',
#        'Plastic Components / Accessories', 'Rigid PVC',
#        'Plastic/LDPE/Polythene Bag', 'Plastic Films & sheets',
#        'Polythene/Plastic Granules', 'Plastic/ PVC Suitcases',
#        'Plastic Bottles', 'Plastic Cabinet', 'Dot pen with refill',
#        'Tooth brush', 'Plastic Containers', 'Plastic/PVC Shoes',
#        'Syringe', 'Polyester Film', 'Polyester Chips',
#        'Expandable Polystyrene', 'V Belt', 'Plastic/PVC Chappals',
#        'Plastic Rolls', 'Polythene/PVC Foam', 'HDPE Bag',
#        'HDPE Woven Sacks', 'HDPE  Woven Fabric', 'Other Plastic Products',
#        'c.  RUBBER PRODUCTS', 'Rubber Seat Assembly',
#        'Seamless Tubes & Pipes', 'Rubber Moulded goods',
#        'Rubber  Foot wear', 'Synthetic rubber compound',
#        'Reclaimed Rubber', 'Rubber Components & Parts',
#        'Automobile  Rubber Padding', 'Rubber Brakes',
#        'Rubber Transmission belt', 'Foot Ball', 'Other Rubber Products',
#        '(H)  CHEMICALS & CHEMICAL PRODUCTS',
#        'a.  BASIC INORGANIC CHEMICALS', "Carbon & It's Compound",
#        'Acid (Inorganic)', 'Caustic Soda & Soda Ash', 'Oxygen',
#        'Lime & Calcium Carbonate', 'Alumina & Aluminium Salt',
#        'Zirconion Silicate', 'Hydrogen Peroxide', 'Titanium Dioxide',
#        'Zinc Oxide', 'Sodium Salt', 'Carbon Di-Sulphide',
#        'Ammonia (Gas / Liquid)', 'Argon Gas', 'Chlorine',
#        'Carbon Dioxide Gas', 'Hydrogen', 'Nitrogen (Gas / Liquid)',
#        'Foundry Chemical', 'Other Inorganic Chemicals',
#        'b.  BASIC ORGANIC CHEMICALS', 'Fatty Acid',
#        'Acetic Acid & Its Derivetives', 'Alcohol &  Mixture', 'Amines',
#        'Glycol', 'Fatty Alcohol', 'Naphthalene / Aniline',
#        'Vegetable Starch', 'Essence/Flavour used in food products.',
#        'Ice Block/ Cube (non edible)', 'Brine Water / Distilled Water',
#        'Organic Solvent', 'Formaldehyde', 'Menthol',
#        'Phenol or Phenol Extract', 'Acid  (Organic)',
#        'Aromatic Chemicals', 'Leather Chemicals',
#        'Petrochemical Building Blocks', 'Other  Organic Chemicals',
#        'c.  FERTILIZERS & PESTICIDES', 'c1.  FERTILIZERS', 'Urea',
#        'Ammonium Sulphate', 'Other Nitrogenous Fertilizer',
#        'Di Ammonium Phosphate', 'Dicalcium Phosphate',
#        'Other Phosphatic Fertilizers', 'Organic Manure',
#        'Fertilizer (Others)', 'c2.  PESTICIDES', 'Endosulfan',
#        'Cypermethrin', 'Weedicides', 'Insecticides', 'Other Pesticides',
#        'd.  PAINTS, VARNISHES & LACQUERS', 'Paints', 'Chemical Colours',
#        'Lacquer & Varnishes', 'Distemper', 'Thinner', 'Ink',
#        'e.  DYESTUFFS & INDIGO', 'Dye & Dye Intermediates',
#        'Pigment & Pigment Intermediates', 'f.  DRUGS & MEDICINES',
#        'Antibiotics', 'Vitamins', 'Vaccines', 'Paracetamol/Analgesic',
#        'Antacid and  Digestive Preparations',
#        'Gelatine Capsules ( empty)', 'Ayurvedic Medicines', 'Others',
#        'g.  PERFUMES, COSMETICS, TOILETRIES ETC', 'Toilet Soap',
#        'Washing Soap', 'Washing Powder', 'Floor Cleaners',
#        'Bleaching Powder', 'Tooth Paste / Tooth Powder',
#        'Hair / Body Oils', 'Perfume / Scent', 'Cream / Moisturizer',
#        'Face / Body Powder', 'Other Flavoured Powder', 'Shampoo', 'Wax',
#        'Shaving Cream', 'Hair Dye', 'h.  TURPENTINE, PLASTIC CHEMICALS',
#        'Thermocol', 'Olio Resin & Gelatin', 'Adhesive &  Gum',
#        'Turpentine Oil', 'Other Plastic Chemicals',
#        'i.  POLYMERS INCLUDING SYNTHETIC RUBBER', 'Polymers',
#        'Synthetic Resin', 'Synthetic  Rubber', 'Polymer Products',
#        'j.  PETROCHEMICAL INTERMEDIATES', 'Non-Cyclic Compound', 'Polyol',
#        'Sulphur & Sulphur Powder', 'Rubber Chemicals',
#        'Other Petrochemical Intermediates',
#        'k.  MATCHES,EXPLOSIVES & OTHER CHEMICALS',
#        'Safety  Matches/ Match Box', 'Explosives', 'Agarbattis',
#        'Photographic Goods', 'Castor Oil', 'Yeast used in Food Industry',
#        'Additives', 'Hardeners', '(I ) NON-METALLIC MINERAL PRODUCTS',
#        'a.  STRUCTURAL CLAY PRODUCTS', 'Bricks & Tiles',
#        'Polished Granite', 'Marbles',
#        'Stone (Chip/Crushed/fFnished/Slab)',
#        'b.  GLASS,EARTHENWARE, CHINAWARE & THEIR PRODUCTS',
#        'Glass Bottles & Bottleware', 'Laminated Glass',
#        'Fibre Glass & Glass Sheet', 'Toughened Glass',
#        'Pressed Glassware', 'Ophthalmic Lens', 'Glass Vials',
#        'Non-Ferrous Sanitary fittings', 'Filter Elements',
#        'Porcelain Crockery', 'c.  CEMENT & LIME', 'Grey Cement',
#        'White Cement', 'Slag  Cement', 'Lime',
#        'd.  CEMENT, SLATE & GRAPHITE PRODUCTS', 'Graphite Rods',
#        'Graphite Amorphous', 'Pencil', 'Asbestos Corrugated Sheet',
#        'Railway Sleeper', 'Concrete Poles & Posts',
#        'Hume Pipes & Spun Pipes', 'Other Cement Product,',
#        '(J)  BASIC METALS, ALLOYS & METAL PRODUCTS', 'a.  FERROUS METALS',
#        'a1.  IRON & SEMIS', 'Sponge Iron', 'Pig Iron', 'Melting Scrap',
#        'Pencil  Ingots', 'Billets', 'Slab', 'a2.  STEEL: LONG', 'Rebars',
#        'Rounds', 'Wire Rods', 'Angles', 'Joist & Beams', 'Rails',
#        'a3.  STEEL: FLAT', 'HRC', 'Plates', 'CRC', 'GP/GC Sheets',
#        'a4.  STEEL: PIPES & TUBES', 'Welded Pipe',
#        'a5.  STAINLESS STEEL & ALLOYS', 'Steel Rods', 'Sheets', 'Steel',
#        'Other Alloys', 'a6.  CASTINGS & FORGINGS', 'Iron Castings',
#        'Steel Castings', 'Die Forging & Stamping', 'a7.  FERRO ALLOYS',
#        'Ferro Chrome', 'Ferro Manganese', 'Ferro Silicon',
#        'b.  NON-FERROUS METALS', 'b1.  ALUMINIUM', 'Aluminium Ingots',
#        'Aluminium Coils/Rolls', 'Aluminium & Alloys', 'Aluminium Casting',
#        'Aluminium Seals', 'Aluminium Foil /Foil Bag',
#        'Aluminium Pipe & Tubes', 'Aluminium  Utensils', 'Aluminium Wire',
#        'b2.  OTHER NON-FERROUS METALS', 'Copper / Copper Ingots',
#        'Copper Wire (All Types)', 'Copper Products (other than wire)',
#        'Brass', 'Zinc', 'Lead', 'Chromium / Chrome', 'Non Ferrous Alloys',
#        'Non-Ferrous Casting & Forging', 'C.   METAL PRODUCTS',
#        'Gold & Gold Ornaments', 'Silver', 'Iron & Steel Wire',
#        'Other Metal Wires & Wire products', 'Nuts/Bolts/Screw/ Washers',
#        'Cylinder', 'Cylinder Liners', 'Steel Structures', 'Steel Balls',
#        'Fabricated Metal Products', 'Furniture', 'Fixtures',
#        'Steel Frames', 'Metal Moulds and Dyes', 'Pipes/Tubes/Rods/Strips',
#        'Cistern Fittings/Iron& steel', 'Welding Rods', 'Metal Containers',
#        'Utensils(other than Aluminium)', 'Pressure Cooker', 'Chain',
#        'Locks', 'Safety Helmet', 'Other Metal Products',
#        '(K)  MACHINERY & MACHINE TOOLS',
#        'a.  AGRICULTURAL MACHINERY & IMPLEMENTS', 'Harvester',
#        'Sprinkler', 'Thresher', 'Separators & Driers',
#        'Other Agriculture Implements', 'b.  INDUSTRIAL MACHINERY',
#        'Boiler & Accessories', 'Industrial Furnaces', 'Coupling',
#        'Filtration Equipment', 'Material Handling Equipments',
#        'Textile Machinery', 'Rubber Machinery', 'Cranes', 'Lifts',
#        'Oil Mill Machinery', 'Rice Mill Machinery', 'Sugar Machinery',
#        'Food/ Beverages/Tobacco Processing Machinery',
#        'Mining/Quarrying/Metallurgical Machinery/Parts.',
#        'Plastic Machinery', 'Fasteners', 'Ball/Roller Bearing',
#        'Pump & Assembly', 'Drive Equipment', 'Heat Exchanger',
#        'Hydraulic Equipment', 'Pneumatic  Tools', 'Industrial  Valves',
#        'Chemical Plant Equipments', 'Other Industrial Machinery',
#        'c.  CONSTRUCTION MACHINERY', 'Loader',
#        'Concrete Vibrator & Mixture',
#        'Other Construction Machinery  / Equipment', 'd.  MACHINE TOOLS',
#        'Drilling Machines', 'Lathes', 'Grinding Wheels',
#        'Cutting Machine', 'Gear Cutting Machines',
#        'e.  AIR CONDITIONER & REFRIGERATORS', 'Air Conditioners',
#        'Refrigerators', 'Chillers', 'f.  NON-ELECTRICAL MACHINERY',
#        'Engines', 'Earth Moving Machinery', 'Compressors',
#        'Meters / Starter (non-electrical)', 'Watches', 'Weighing Scales',
#        'Sewing Machines', 'Solar Power System & Windmill',
#        'Other Non Electrical Machinery',
#        'g.  ELECTRICAL MACHINERY, EQUIPMENT & BATTERIES',
#        'Electrical Pumps', 'Transformer', 'Electric Motors',
#        'Power Supply (DC)', 'Electric Switch Gears', 'Relay /Contacter',
#        'Electric  Connectors / Plugs /Sockets/Holders',
#        'Electrolytic Condensers', 'Electric Switches',
#        'Converter / Inverter', 'Electric Generators',
#        'Electric Motor Starters', 'Control equipments', 'Regulators',
#        'Distribution Boards', 'Other Electric Meter',
#        'Electrical Stamping Lamination', 'Electrical Signaling Equipment',
#        'Batteries', 'Battery Dry cells', 'Battery Charger',
#        'Other Electric  Machinery & Equipments',
#        'h.  ELECTRICAL ACCESSORIES, WIRES, CABLES ETC.', 'Conductor',
#        'Insulators', 'Lamps', 'Magnets', 'Fluorescent Tubes',
#        'Air Break Switches/Circuit Breaker', 'PVC Insulated Cable',
#        'Kit-Kat /Fuse / Fuse wire', 'Electrical Wires',
#        'Heating Elements', 'Other Electric Accessories',
#        'i.  ELECTRICAL APPARATUS & APPLIANCES',
#        'Washing / Laundry Machines', 'Fans',
#        'Grinding /Wet Coffee Machinery', 'Flash Light/ Torch',
#        'UPS / Stabilizer', 'Microwave Oven', 'j.  ELECTRONICS ITEMS',
#        'T.V.Sets', 'T.V. Accessories', 'Sensors', 'Optical Instruments',
#        'Video CD Player', 'Resistance /Resistor', 'Semiconductor Devices',
#        'Capacitors', 'Electronic PCB /Micro Circuit', 'Amplifier',
#        'Computer Power Supply System (SMPS)', 'Fibre Optic Cable',
#        'Other Electronics Items', 'k.  IT HARDWARE', 'Computers',
#        'Computer Peripherals', 'l.  COMMUNICATION EQUIPMENTS',
#        'Telecommunication Exchange', 'Dish Antenna',
#        'Other Communication Equipments',
#        '(L)  TRANSPORT, EQUIPMENT & PARTS', 'a.  AUTOMOTIVES',
#        'Motor Vehicles', 'Tractors', 'Bus / Mini bus / Truck',
#        'Auto Rickshaw / Tempo / Matador', 'Motor Cycle / Scooter / Moped',
#        'Trolleys / Tanker', 'b.  AUTO PARTS', 'Gear Boxes & Parts',
#        'Steering Gears', 'Carburetors', 'Clutch & Clutch Plates',
#        'Crankshafts', 'Suspension', 'Axle', 'Wheels & Parts',
#        'Fuel Injection Equipments', 'Silencer & Damper',
#        'Wiper/Blade/Arm etc', 'Piston & Compressor',
#        'Coil Assembly (Ignition)', 'Slider', 'Engine Assembly & Chassis',
#        'Gauges', 'Geared Motor', 'Radiator & Coolers',
#        'Electric Magnet Brakes', 'Lamp', 'Horn',
#        'c.  OTHER TRANSPORT EQUIPMENTS', 'Railway Brake Gear',
#        'Railway  Axle & wheel', 'Other Rail Equipments', 'Bi-Cycles',
#        'Parts of Ships/Boats etc.', 'Shafts (All Kinds)'], dtype=object)

# %%
import matplotlib.pyplot as plt

# Set index to COMMODITIES
df_4.set_index('COMMODITIES', inplace=True)

# %%
# Plot WPI trend for 'Rice'
df_4.loc['Rice'].drop(['Weight']).T.plot(figsize=(10,6))
plt.title('WPI Trend for Rice')
plt.xlabel('Month')
plt.ylabel('WPI')
plt.xticks(rotation=90)  # Rotate month labels for better visibility
plt.show()

# %%
# Plot WPI trend for 'Rice' and 'Wheat'
df_4.loc[['Rice', 'Wheat',
       'Jowar', 'Bajra', 'Maize', 'Barley', 'Ragi']].drop(['Weight'], axis=1).T.plot(figsize=(10,6))
plt.title('WPI Trend for Rice and Wheat')
plt.xlabel('Month')
plt.ylabel('WPI')
plt.xticks(rotation=90)
plt.show()

# %%
df_4.head()
# Out:
#                                     Weight     1     2     3      4      5  \
# COMMODITIES
# ALL COMMODITIES                  100.00000  97.5  98.0  98.3   99.2  100.6
# I    PRIMARY ARTICLES             20.11815  97.0  98.5  99.0  101.0  103.5
# (A)  FOOD ARTICLES                14.33709  97.5  98.5  98.8  100.7  103.0
# a.  FOOD GRAINS(CEREALS+PULSES)    4.08982  96.7  97.3  97.8   98.2  100.1
# a1. CEREALS                        3.37323  96.0  96.9  97.4   97.7   99.5
#
#                                      6      7      8      9  ...    147  \
# COMMODITIES                                                  ...
# ALL COMMODITIES                  100.5  100.7  101.5  100.5  ...  182.9
# I    PRIMARY ARTICLES            102.2  102.9  103.7   98.6  ...  265.5
# (A)  FOOD ARTICLES               101.1  102.4  105.2   99.4  ...  280.0
# a.  FOOD GRAINS(CEREALS+PULSES)  100.3  100.4  106.1  100.6  ...  275.6
# a1. CEREALS                       99.6   99.9  107.3  101.0  ...  249.1
#
#                                    148    149    150    151    152    153  \
# COMMODITIES
# ALL COMMODITIES                  184.2  183.3  183.2  183.6  183.5  183.3
# I    PRIMARY ARTICLES            270.4  269.6  265.4  264.0  261.2  257.9
# (A)  FOOD ARTICLES               287.8  285.9  281.3  280.0  277.6  269.9
# a.  FOOD GRAINS(CEREALS+PULSES)  285.9  286.6  283.0  288.0  294.7  293.2
# a1. CEREALS                      253.0  254.4  255.0  254.7  258.9  260.8
#
#                                    154    155    156
# COMMODITIES
# ALL COMMODITIES                  185.1  185.5  185.3
# I    PRIMARY ARTICLES            258.2  258.9  257.5
# (A)  FOOD ARTICLES               268.3  268.6  267.6
# a.  FOOD GRAINS(CEREALS+PULSES)  283.3  276.8  265.9
# a1. CEREALS                      260.0  260.7  253.3
#
# [5 rows x 157 columns]

# %%
# Plot WPI trend for 'Rice'
df_4.loc['ALL COMMODITIES'].drop(['Weight']).T.plot(figsize=(10,6))
plt.title('WPI Trend for ALL COMMODITIES')
plt.xlabel('Month')
plt.ylabel('WPI')
plt.xticks(rotation=90)  # Rotate month labels for better visibility
plt.show()

# %%
avg_growth_rate=df_4.pct_change(axis=1).mean(axis=1)

# %%
# Calculate the average monthly growth rate
avg_growth_rate = df_4.pct_change(axis=1).mean(axis=1)

# Sort in descending order and get the top 10 commodities
top_10_growth_rate = avg_growth_rate.sort_values(ascending=False).head(10)

# Display the top 10 commodities with the highest growth rate
print(top_10_growth_rate)
# Out:
# COMMODITIES
# Fireclay               1573.890872
# Sillimanite             971.249988
# Steatite                788.837784
# Graphite                730.934710
# Safety Helmet           689.269497
# Slider                  585.155909
# Gauges                  571.766870
# Barytes                 335.196683
# Gypsum                  266.736711
# Wiper/Blade/Arm etc     174.187519
# dtype: float64

# %%
df_4.loc['Sillimanite'].drop(['Weight']).T.plot(figsize=(10,6))
plt.title('WPI Trend')
plt.xlabel('Month')
plt.ylabel('WPI')
plt.xticks(rotation=90)  # Rotate month labels for better visibility
plt.show()

# %%
# Compute the correlation matrix
correlation_matrix = df_4.T.corr()

# Plot the heatmap
plt.figure(figsize=(12, 10))  # Adjust the size as needed
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Matrix of Commodities')
plt.show()
# Out:
# KeyboardInterrupt

# %%
print('hell')
